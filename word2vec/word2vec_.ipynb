# %%
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
import torch.nn.functional as F
import spacy
import pandas as pd
import re
import string
from time import time

# %%
df = pd.read_csv('imdb_master.csv', encoding="latin-1")
df.shape
# Out:
# (499, 5)

# %%
df.head()
# Out:
#    Unnamed: 0  type                                             review label  \
# 0           0  test  Once again Mr. Costner has dragged out a movie...   neg
# 1           1  test  This is an example of why the majority of acti...   neg
# 2           2  test  First of all I hate those moronic rappers, who...   neg
# 3           3  test  Not even the Beatles could write songs everyon...   neg
# 4           4  test  Brass pictures (movies is not a fitting word f...   neg
#
#           file
# 0      0_2.txt
# 1  10000_4.txt
# 2  10001_1.txt
# 3  10002_3.txt
# 4  10003_3.txt

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# type          0
# review        0
# label         0
# file          0
# dtype: int64

# %%
df = df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# Unnamed: 0    0
# type          0
# review        0
# label         0
# file          0
# dtype: int64

# %%
nlp = spacy.load('en_core_web_sm')

def cleaning(doc):
    txt = [token.lemma_ for token in doc if not token.is_stop]
    if len(txt) > 2:
        return ' '.join(txt)

# %%
brief_cleaning = (str(row).lower() for row in df['review'])

# %%
t = time()

txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=128)]

# %%
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (499, 1)

# %%
all_txt = ""

for row in df_clean['clean']:
    all_txt = all_txt + row

# %%
class CBOW(nn.Module):
    def __init__(self, context_size=2, embedding_size=256, vocab_size=None):
        super(CBOW, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_size)
        self.linear1 = nn.Linear(embedding_size, vocab_size)

    def forward(self, inputs):
        lookup_embeds = self.embeddings(inputs)
        embeds = lookup_embeds.sum(dim=0)
        out = self.linear1(embeds)
        out = F.log_softmax(out, dim=0)
        return out

# %%
def make_context_vector(context, word_to_ix):
    idxs = [word_to_ix[w] for w in context]
    tensor = torch.LongTensor(idxs).to('cuda')
    return autograd.Variable(tensor)

# %%
CONTEXT_SIZE = 1
EMBEDDING_SIZE = 256
# raw_text = all_txt.split()
raw_text = re.findall( r'\w+|[^\s\w]+', all_txt)

vocab = set(raw_text)
vocab_size = len(vocab)

word_to_ix = {word: i for i, word in enumerate(vocab)}
print(word_to_ix.keys())

word_to_ix_ = {}

i = 0
for row in word_to_ix:
    word = row.translate(str.maketrans("", "", string.punctuation))
    if word != '':
        word_to_ix_[word] = i
    else:
        i -= 1
    i += 1

word_to_ix = word_to_ix_

print(word_to_ix.keys())

data = []
for i in range(2, len(raw_text) - 2):
    context = [raw_text[i - 1].translate(str.maketrans("", "", string.punctuation)), raw_text[i + 1].translate(str.maketrans("", "", string.punctuation))]
    target = raw_text[i]
    data.append((context, target))

loss_func = nn.CrossEntropyLoss()
net = CBOW(CONTEXT_SIZE, embedding_size=EMBEDDING_SIZE, vocab_size=vocab_size).to('cuda')
optimizer = optim.SGD(net.parameters(), lr=0.001) #optimize lr

for epoch in range(30):
    total_loss = 0
    iterations = 0
    for context, target in data:

        i = 0
        prev_word = "blank"
        for val in context:
            word = val.translate(str.maketrans("", "", string.punctuation))
            if word != '':
                context[i] = word
                prev_word = word
            else:
                if i == 0:
                    if context[0] == context[1] == '':
                        context[0] = 'blank'
                        prev_word = 'blank'
                    else:
                        i -= 1
                else:
                    context[i] = prev_word
            i += 1

        word = target.translate(str.maketrans("", "", string.punctuation))
        if word != '':
            target = word
        else:
            if i == 0:
                i -= 1
            else:
                target = prev_word

        context_var = make_context_vector(context, word_to_ix)
        net.zero_grad()
        log_probs = net(context_var)

        loss = loss_func(log_probs.view(1,-1), autograd.Variable(
            torch.LongTensor([word_to_ix[target.translate(str.maketrans("", "", string.punctuation))]]).to('cuda')
        ))

        loss.backward()
        optimizer.step()

        iterations += 1
        total_loss += loss.data
    print(total_loss / iterations)
# Out:
# dict_keys(['pseudo', 'divorce', 'treat', 'discuss', 'sulk', 'dern', 'undercover', 'height', 'column', 'determine', 'apology', 'ford', 'smell', 'afterlife', 'urge', 'forewarn', 'filth', 'craze', 'cafe', 'laura', 'shopping', 'june', 'la', 'builder', 'delight', 'satisfied', 'mafioso', 'magazine', 'owner', 'vibrant', 'madkaughmovie', 'protestant', 'unconventional', 'hack', 'valid', 'wars', 'family', 'pm', 'offs', 'schneider', 'cling', 'captain', 'ordinary', 'rendition', 'stunned', 'performance', 'alert', 'official', 'yakima', 'snot', 'dracula', 'pilot', 'derek', 'separate', 'megaloadon', 'video', 'rental', 'improvisation', 'bowl', 'bargain', 'simon', '06', 'plentiful', 'cuff', 'lobotomy', 'curiously', 'sea', 'sparseness', 'montana', 'ball', 'mocumentary', 'raise', 'smith', 'x100', 'disc', 'brett', 'uplift', 'btw', 'drown', 'even', 'animation', 'unrecognizable', 'jeffery', 'equally', 'poop', 'yellow', 'tenser', 'krakowsky', 'schwarzenegger', 'type', 'paralysis', 'pickle', 'twitch', 'unemployed', 'thursday', 'believed', 'progressively', 'ceremony', 'justify', 'final', 'descriptive', '100', 'modeling', 'neccessary', 'kinky', 'haired', 'destine', 'vocalist', 'freakin', 'reputation', 'overact', 'pun', 'skinned', 'engaging', 'moderately', 'nice', 'ominous', 'contradict', 'defense', 'powell', 'few', 'undeniably', 'hairstyle', 'installment', 'bet', 'strike', 'newscaster', 'ustinov', 'adaptation', 'arden', 'aussie', 'female', 'firmly', 'honcho', 'presidential', 'tell', 'roster', 'elevation', 'homeless', 'superior', 'symbolism', 'punish', 'scorsese', 'corruption', 'redo', 'speaking', 'brigitte', 'soundboard', 'attend', 'district', 'suite', 'surgical', 'pontoon', 'geographically', 'rain', 'street', '...', 'poison', 'vehicle', 'attempt', 'playing', 'raw', 'intolerance', 'hand', 'schroder', 'juvinile', 'comconnoisseur', 'transsexual', 'karol', 'riverside', 'spaceball', 'earphone', 'huge', 'maniacal', 'understand', 'yike', 'insane', 'alternate', 'wide', 'ultimately', 'muller', 'lightning', 'bed', 'reflection', 'mention', 'college', 'bachelor', 'yell', 'magda', 'endearing', 'infinity', 'logic', 'kane', 'hollywood', 'doable', 'clerk', 'logically', '.(', 'filmographie', 'regan', 'reservation', 'nearly', 'threesome', 'woah', 'mirren', 'hannah', 'spacecraft', 'fourth', 'lovemaking', 'boost', '~', 'ps', 'unflattering', 'scenery', 'cheesiest', 'idea', 'true', 'dippity', 'second', 'loose', 'blunder', 'relive', 'weigh', 'storytelling', 'outcome', 'wholesome', 'disease', 'wayne', 'brat', 'momma', '14', 'spiritual', 'insular', 'watching', 'fight', 'overrate', 'robbin', 'pretense', 'randolph', 'pinhead', 'corleone', 'carnosaur', 'research', 'mega', 'bah', 'realistic', 'appetizer', '10movie', 'digest', 'exhibition', 'horserace', 'leave', 'profundity', 'catholic', 'cook', 'understandably', 'enchanted', 'scheduler', 'mild', 'wave', 'steady', 'decry', 'wee', 'catharsis', 'ought', 'earning', 'adult', 'halt', 'intelligibly', 'scifi', '911', 'secularist', 'lpwa', 'seasoned', 'cosy', 'cocoon', 'actual', 'scatter', 'ignorance', 'overdone', 'cor', 'tiny', 'wonderful', 'kwik', 'iceberg', 'bash', 'known', 'drip', 'insanity', 'ever', 'bombshell', 'haymes', 'angeles', 'gremlin', 'belligerence', 'appointment', 'more', 'witness', 'selling', 'armful', 'mock', 'spencer', 'smooth', 'nothe', 'lauter', 'plaguelike', 'hitchhiker', 'deranged', 'scattershot', 'sundown', 'quest', 'pique', 'melodramatic', 'parts', 'advice', 'senseless', 'surround', 'outta', 'tight', 'advisable', 'descibe', 'clerical', 'eg', 'bratty', 'suffer', 'uncut', 'mario', 'houstonian', 'withï', 'ummm', 'circumstance', 'blow', 'inconsequential', 'musical', 'sermon', 'el', 'literal', 'detail', 'peerce', 'basketball', 'klan', 'goodman', 'moronically', '60mph', 'invader', 'bloke', 'alma', 'ritchie', 'shaymalan', 'phenomena', 'cohesive', 'molest', 'sorry', 'establishment', 'crack', 'gnostic', 'ensue', 'jarring', 'jewel', 'midwest', 'tattoo', ')', 'list', 'forgettable', 'extraterrestrial', 'ballet', 'slender', 'cry ...
# dict_keys(['pseudo', 'divorce', 'treat', 'discuss', 'sulk', 'dern', 'undercover', 'height', 'column', 'determine', 'apology', 'ford', 'smell', 'afterlife', 'urge', 'forewarn', 'filth', 'craze', 'cafe', 'laura', 'shopping', 'june', 'la', 'builder', 'delight', 'satisfied', 'mafioso', 'magazine', 'owner', 'vibrant', 'madkaughmovie', 'protestant', 'unconventional', 'hack', 'valid', 'wars', 'family', 'pm', 'offs', 'schneider', 'cling', 'captain', 'ordinary', 'rendition', 'stunned', 'performance', 'alert', 'official', 'yakima', 'snot', 'dracula', 'pilot', 'derek', 'separate', 'megaloadon', 'video', 'rental', 'improvisation', 'bowl', 'bargain', 'simon', '06', 'plentiful', 'cuff', 'lobotomy', 'curiously', 'sea', 'sparseness', 'montana', 'ball', 'mocumentary', 'raise', 'smith', 'x100', 'disc', 'brett', 'uplift', 'btw', 'drown', 'even', 'animation', 'unrecognizable', 'jeffery', 'equally', 'poop', 'yellow', 'tenser', 'krakowsky', 'schwarzenegger', 'type', 'paralysis', 'pickle', 'twitch', 'unemployed', 'thursday', 'believed', 'progressively', 'ceremony', 'justify', 'final', 'descriptive', '100', 'modeling', 'neccessary', 'kinky', 'haired', 'destine', 'vocalist', 'freakin', 'reputation', 'overact', 'pun', 'skinned', 'engaging', 'moderately', 'nice', 'ominous', 'contradict', 'defense', 'powell', 'few', 'undeniably', 'hairstyle', 'installment', 'bet', 'strike', 'newscaster', 'ustinov', 'adaptation', 'arden', 'aussie', 'female', 'firmly', 'honcho', 'presidential', 'tell', 'roster', 'elevation', 'homeless', 'superior', 'symbolism', 'punish', 'scorsese', 'corruption', 'redo', 'speaking', 'brigitte', 'soundboard', 'attend', 'district', 'suite', 'surgical', 'pontoon', 'geographically', 'rain', 'street', 'poison', 'vehicle', 'attempt', 'playing', 'raw', 'intolerance', 'hand', 'schroder', 'juvinile', 'comconnoisseur', 'transsexual', 'karol', 'riverside', 'spaceball', 'earphone', 'huge', 'maniacal', 'understand', 'yike', 'insane', 'alternate', 'wide', 'ultimately', 'muller', 'lightning', 'bed', 'reflection', 'mention', 'college', 'bachelor', 'yell', 'magda', 'endearing', 'infinity', 'logic', 'kane', 'hollywood', 'doable', 'clerk', 'logically', 'filmographie', 'regan', 'reservation', 'nearly', 'threesome', 'woah', 'mirren', 'hannah', 'spacecraft', 'fourth', 'lovemaking', 'boost', 'ps', 'unflattering', 'scenery', 'cheesiest', 'idea', 'true', 'dippity', 'second', 'loose', 'blunder', 'relive', 'weigh', 'storytelling', 'outcome', 'wholesome', 'disease', 'wayne', 'brat', 'momma', '14', 'spiritual', 'insular', 'watching', 'fight', 'overrate', 'robbin', 'pretense', 'randolph', 'pinhead', 'corleone', 'carnosaur', 'research', 'mega', 'bah', 'realistic', 'appetizer', '10movie', 'digest', 'exhibition', 'horserace', 'leave', 'profundity', 'catholic', 'cook', 'understandably', 'enchanted', 'scheduler', 'mild', 'wave', 'steady', 'decry', 'wee', 'catharsis', 'ought', 'earning', 'adult', 'halt', 'intelligibly', 'scifi', '911', 'secularist', 'lpwa', 'seasoned', 'cosy', 'cocoon', 'actual', 'scatter', 'ignorance', 'overdone', 'cor', 'tiny', 'wonderful', 'kwik', 'iceberg', 'bash', 'known', 'drip', 'insanity', 'ever', 'bombshell', 'haymes', 'angeles', 'gremlin', 'belligerence', 'appointment', 'more', 'witness', 'selling', 'armful', 'mock', 'spencer', 'smooth', 'nothe', 'lauter', 'plaguelike', 'hitchhiker', 'deranged', 'scattershot', 'sundown', 'quest', 'pique', 'melodramatic', 'parts', 'advice', 'senseless', 'surround', 'outta', 'tight', 'advisable', 'descibe', 'clerical', 'eg', 'bratty', 'suffer', 'uncut', 'mario', 'houstonian', 'withï', 'ummm', 'circumstance', 'blow', 'inconsequential', 'musical', 'sermon', 'el', 'literal', 'detail', 'peerce', 'basketball', 'klan', 'goodman', 'moronically', '60mph', 'invader', 'bloke', 'alma', 'ritchie', 'shaymalan', 'phenomena', 'cohesive', 'molest', 'sorry', 'establishment', 'crack', 'gnostic', 'ensue', 'jarring', 'jewel', 'midwest', 'tattoo', 'list', 'forgettable', 'extraterrestrial', 'ballet', 'slender', 'cry', 'logger', 'necessary ...
# tensor([4798, 4798], device='cuda:0')
# tensor([4530, 7050], device='cuda:0')
# tensor([4798, 4954], device='cuda:0')
# tensor([7050, 4742], device='cuda:0')
# tensor([4954,  365], device='cuda:0')
# tensor([4742, 4742], device='cuda:0')
# tensor([ 365, 6118], device='cuda:0')
# tensor([7023, 7023], device='cuda:0')
# tensor([6118,   66], device='cuda:0')
# tensor([7023, 6607], device='cuda:0')
# tensor([  66, 4216], device='cuda:0')
# tensor([6607, 6607], device='cuda:0')
# tensor([4216, 4737], device='cuda:0')
# tensor([7451, 7451], device='cuda:0')
# tensor([4737, 4737], device='cuda:0')
# tensor([7451, 6071], device='cuda:0')
# tensor([3195, 3195], device='cuda:0')
# tensor([6071, 6071], device='cuda:0')
# tensor([3195, 4530], device='cuda:0')
# tensor([7451, 7451], device='cuda:0')
# tensor([4530,  574], device='cuda:0')
# tensor([7451, 7892], device='cuda:0')
# tensor([574, 574], device='cuda:0')
# tensor([7892, 2904], device='cuda:0')
# tensor([2661, 2661], device='cuda:0')
# tensor([2904, 2904], device='cuda:0')
# tensor([2661,  693], device='cuda:0')
# tensor([4737, 4737], device='cuda:0')
# tensor([693, 693], device='cuda:0')
# tensor([4737, 7451], device='cuda:0')
# tensor([4737, 4737], device='cuda:0')
# tensor([7451, 1514], device='cuda:0')
# tensor([4737, 4737], device='cuda:0')
# tensor([1514, 4527], device='cuda:0')
# tensor([8282, 8282], device='cuda:0')
# tensor([4527, 1300], device='cuda:0')
# tensor([8282, 8282], device='cuda:0')
# tensor([1300, 2887], device='cuda:0')
# tensor([6058, 6058], device='cuda:0')
# tensor([2887,  794], device='cuda:0')
# tensor([6058, 5573], device='cuda:0')
# tensor([ 794, 2483], device='cuda:0')
# tensor([5573, 2580], device='cuda:0')
# tensor([2483, 6242], device='cuda:0')
# tensor([2580, 7629], device='cuda:0')
# tensor([6242, 3195], device='cuda:0')
# tensor([7629, 7629], device='cuda:0')
# tensor([3195, 6388], device='cuda:0')
# tensor([4990, 4990], device='cuda:0')
# tensor([6388, 5265], device='cuda:0')
# tensor([4990, 4530], device='cuda:0')
# tensor([5265, 5265], device='cuda:0')
# tensor([4530, 4419], device='cuda:0')
# tensor([2142, 2142], device='cuda:0')
# tensor([4419, 1695], device='cuda:0')
# tensor([2142, 3513], device='cuda:0')
# tensor([1695, 4013], device='cuda:0')
# tensor([3513, 4575], device='cuda:0')
# tensor([4013, 4013], device='cuda:0')
# tensor([4575, 4530], device='cuda:0')
# tensor([135, 135], device='cuda:0')
# tensor([4530, 1300], device='cuda:0')
# tensor([ 135, 6071], device='cuda:0')
# tensor([1300, 1300], device='cuda:0')
# tensor([6071,  135], device='cuda:0')
# tensor([1300, 1300], device='cuda:0')
# tensor([ 135, 7990], device='cuda:0')
# tensor([1300, 6936], device='cuda:0')
# tensor([7990, 7933], device='cuda:0')
# tensor([6936, 5724], device='cuda:0')
# tensor([7933, 5577], device='cuda:0')
# tensor([5724, 5724], device='cuda:0')
# tensor([5577, 2705], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([2705, 2604], device='cuda:0')
# tensor([6158, 6158], device='cuda:0')
# tensor([2604, 2604], device='cuda:0')
# tensor([6158, 4172], device='cuda:0')
# tensor([6401, 6401], device='cuda:0')
# tensor([4172, 6850], device='cuda:0')
# tensor([6401, 2870], device='cuda:0')
# tensor([6850, 6850], device='cuda:0')
# tensor([2870, 7248], device='cuda:0')
# tensor([2912, 2912], device='cuda:0')
# tensor([7248, 7248], device='cuda:0')
# tensor([2912, 8069], device='cuda:0')
# tensor([3618, 3618], device='cuda:0')
# tensor([8069, 8069], device='cuda:0')
# tensor([3618, 5918], device='cuda:0')
# tensor([1769, 1769], device='cuda:0')
# tensor([5918, 7452], device='cuda:0')
# tensor([1769, 1769], device='cuda:0')
# tensor([7452, 7741], device='cuda:0')
# tensor([2779, 2779], device='cuda:0')
# tensor([7741, 3854], device='cuda:0')
# tensor([2779, 2779], device='cuda:0')
# tensor([3854, 3857], device='cuda:0')
# tensor([3854, 3854], device='cuda:0')
# tensor([3857, 8411], device='cuda:0')
# tensor([3854, 3854], device='cuda:0')
# tensor([8411, 1389], device='cuda:0')
# tensor([693, 693], device='cuda:0')
# tensor([1389, 8469], device='cuda:0')
# tensor([ 693, 5590], device='cuda:0')
# tensor([8469, 8469], device='cuda:0')
# tensor([5590, 5590], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([5590, 5745], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([5745, 1336], device='cuda:0')
# tensor([4079, 4079], device='cuda:0')
# tensor([1336, 1720], device='cuda:0')
# tensor([4079, 4079], device='cuda:0')
# tensor([1720, 6566], device='cuda:0')
# tensor([3618, 3618], device='cuda:0')
# tensor([6566, 1336], device='cuda:0')
# tensor([3618, 1131], device='cuda:0')
# tensor([1336,    6], device='cuda:0')
# tensor([1131, 3854], device='cuda:0')
# tensor([6, 6], device='cuda:0')
# tensor([3854, 3857], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3857, 5316], device='cuda:0')
# tensor([7682, 7682], device='cuda:0')
# tensor([5316, 4092], device='cuda:0')
# tensor([7682, 7682], device='cuda:0')
# tensor([4092, 3812], device='cuda:0')
# tensor([4185, 4185], device='cuda:0')
# tensor([3812, 2967], device='cuda:0')
# tensor([4185, 3854], device='cuda:0')
# tensor([2967, 8411], device='cuda:0')
# tensor([3854, 7838], device='cuda:0')
# tensor([8411, 3004], device='cuda:0')
# tensor([7838, 7838], device='cuda:0')
# tensor([3004, 3854], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3854, 3857], device='cuda:0')
# tensor([8538, 8538], device='cuda:0')
# tensor([3857, 4991], device='cuda:0')
# tensor([8538, 6986], device='cuda:0')
# tensor([4991, 3849], device='cuda:0')
# tensor([6986, 2870], device='cuda:0')
# tensor([3849, 1299], device='cuda:0')
# tensor([2870, 6757], device='cuda:0')
# tensor([1299, 1299], device='cuda:0')
# tensor([6757, 4571], device='cuda:0')
# tensor([8595, 8595], device='cuda:0')
# tensor([4571, 6807], device='cuda:0')
# tensor([8595, 8663], device='cuda:0')
# tensor([6807, 2870], device='cuda:0')
# tensor([8663, 8663], device='cuda:0')
# tensor([2870, 8595], device='cuda:0')
# tensor([3549, 3549], device='cuda:0')
# tensor([8595, 4108], device='cuda:0')
# tensor([3549, 7451], device='cuda:0')
# tensor([4108, 4108], device='cuda:0')
# tensor([7451, 7272], device='cuda:0')
# tensor([5239, 5239], device='cuda:0')
# tensor([7272, 7272], device='cuda:0')
# tensor([5239, 2870], device='cuda:0')
# tensor([7020, 7020], device='cuda:0')
# tensor([2870, 6807], device='cuda:0')
# tensor([7020, 8663], device='cuda:0')
# tensor([6807, 3549], device='cuda:0')
# tensor([8663, 4108], device='cuda:0')
# tensor([3549, 7999], device='cuda:0')
# tensor([4108, 7451], device='cuda:0')
# tensor([7999, 7999], device='cuda:0')
# tensor([7451, 7272], device='cuda:0')
# tensor([7451, 7451], device='cuda:0')
# tensor([7272, 8199], device='cuda:0')
# tensor([7451, 7451], device='cuda:0')
# tensor([8199, 1798], device='cuda:0')
# tensor([5520, 5520], device='cuda:0')
# tensor([1798, 1798], device='cuda:0')
# tensor([5520, 5520], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605,  475], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([475, 215], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([ 215, 5332], device='cuda:0')
# tensor([6850, 6850], device='cuda:0')
# tensor([5332, 6846], device='cuda:0')
# tensor([6850, 6850], device='cuda:0')
# tensor([6846, 2577], device='cuda:0')
# tensor([2483, 2483], device='cuda:0')
# tensor([2577, 2870], device='cuda:0')
# tensor([2483, 2483], device='cuda:0')
# tensor([2870, 1302], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([1302, 3618], device='cuda:0')
# tensor([6181, 6181], device='cuda:0')
# tensor([3618, 2990], device='cuda:0')
# tensor([6181, 6181], device='cuda:0')
# tensor([2990, 8630], device='cuda:0')
# tensor([6146, 6146], device='cuda:0')
# tensor([8630, 3330], device='cuda:0')
# tensor([6146, 2483], device='cuda:0')
# tensor([3330, 5590], device='cuda:0')
# tensor([2483, 2483], device='cuda:0')
# tensor([5590, 1980], device='cuda:0')
# tensor([2483, 2483], device='cuda:0')
# tensor([1980, 2396], device='cuda:0')
# tensor([8069, 8069], device='cuda:0')
# tensor([2396, 3618], device='cuda:0')
# tensor([8069, 6357], device='cuda:0')
# tensor([3618,  162], device='cuda:0')
# tensor([6357,  830], device='cuda:0')
# tensor([162, 162], device='cuda:0')
# tensor([ 830, 1665], device='cuda:0')
# tensor([5679, 5679], device='cuda:0')
# tensor([1665, 1665], device='cuda:0')
# tensor([5679, 6058], device='cuda:0')
# tensor([5111, 5111], device='cuda:0')
# tensor([6058, 3849], device='cuda:0')
# tensor([5111, 8447], device='cuda:0')
# tensor([3849, 2870], device='cuda:0')
# tensor([8447, 8447], device='cuda:0')
# tensor([2870, 2870], device='cuda:0')
# tensor([4485, 4485], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([4485, 5431], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([5431, 1432], device='cuda:0')
# tensor([6725, 6725], device='cuda:0')
# tensor([1432, 3722], device='cuda:0')
# tensor([6725, 6725], device='cuda:0')
# tensor([3722, 2278], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([2278, 5580], device='cuda:0')
# tensor([5590, 5590], device='cuda:0')
# tensor([5580, 2206], device='cuda:0')
# tensor([5590, 2652], device='cuda:0')
# tensor([2206, 3145], device='cuda:0')
# tensor([2652, 2652], device='cuda:0')
# tensor([3145, 1583], device='cuda:0')
# tensor([3415, 3415], device='cuda:0')
# tensor([1583, 5590], device='cuda:0')
# tensor([3415, 1255], device='cuda:0')
# tensor([5590, 3878], device='cuda:0')
# tensor([1255, 3169], device='cuda:0')
# tensor([3878, 3878], device='cuda:0')
# tensor([3169, 7294], device='cuda:0')
# tensor([4295, 4295], device='cuda:0')
# tensor([7294, 2643], device='cuda:0')
# tensor([4295, 4295], device='cuda:0')
# tensor([2643, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 2841], device='cuda:0')
# tensor([7050, 7050], device='cuda:0')
# tensor([2841, 1086], device='cuda:0')
# tensor([7050,  629], device='cuda:0')
# tensor([1086, 8182], device='cuda:0')
# tensor([ 629, 1215], device='cuda:0')
# tensor([8182, 3893], device='cuda:0')
# tensor([1215, 1904], device='cuda:0')
# tensor([3893, 7451], device='cuda:0')
# tensor([1904, 7050], device='cuda:0')
# tensor([7451, 7451], device='cuda:0')
# tensor([7050,  138], device='cuda:0')
# tensor([2869, 2869], device='cuda:0')
# tensor([138, 138], device='cuda:0')
# tensor([2869, 1695], device='cuda:0')
# tensor([5354, 5354], device='cuda:0')
# tensor([1695, 1695], device='cuda:0')
# tensor([5354, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 6807], device='cuda:0')
# tensor([8663, 8663], device='cuda:0')
# tensor([6807, 5104], device='cuda:0')
# tensor([8663, 5825], device='cuda:0')
# tensor([5104, 6314], device='cuda:0')
# tensor([5825, 7032], device='cuda:0')
# tensor([6314, 5825], device='cuda:0')
# tensor([7032, 7451], device='cuda:0')
# tensor([5825, 3579], device='cuda:0')
# tensor([7451, 3370], device='cuda:0')
# tensor([3579, 3579], device='cuda:0')
# tensor([3370, 8648], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8648, 5580], device='cuda:0')
# tensor([1255, 1255], device='cuda:0')
# tensor([5580,  893], device='cuda:0')
# tensor([1255, 1598], device='cuda:0')
# tensor([893, 893], device='cuda:0')
# tensor([1598, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 2841], device='cuda:0')
# tensor([7050, 7050], device='cuda:0')
# tensor([2841, 6817], device='cuda:0')
# tensor([7050, 7177], device='cuda:0')
# tensor([6817, 7201], device='cuda:0')
# tensor([7177, 3705], device='cuda:0')
# tensor([7201, 3431], device='cuda:0')
# tensor([3705, 6425], device='cuda:0')
# tensor([3431, 3431], device='cuda:0')
# tensor([6425, 5267], device='cuda:0')
# tensor([929, 929], device='cuda:0')
# tensor([5267, 3651], device='cuda:0')
# tensor([ 929, 3297], device='cuda:0')
# tensor([3651, 8130], device='cuda:0')
# tensor([3297, 3297], device='cuda:0')
# tensor([8130, 3988], device='cuda:0')
# tensor([8605, 8605], device='cuda:0')
# tensor([3988, 5216], device='cuda:0')
# tensor([8605, 2887], device='cuda:0')
# tensor([5216, 2541], device='cuda:0')
# tensor([2887, 2887], device='cuda:0')
# tensor([2541, 2541], device='cuda:0')
# tensor([8168, 8168], device='cuda:0')
# tensor([8199, 8199], device='cuda:0')
# tensor([8168, 8168], device='cuda:0')
# tensor([8199, 8663], device='cuda:0')
# tensor([138, 138], device='cuda:0')
# tensor([8663, 2869], device='cuda:0')
# tensor([ 138, 8168], device='cuda:0')
# tensor([2869, 8170], device='cuda:0')
# tensor([8168, 8168], device='cuda:0')
# tensor([8170, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 2841], device='cuda:0')
# tensor([8696, 8696], device='cuda:0')
# tensor([2841, 5267], device='cuda:0')
# tensor([8696, 5590], device='cuda:0')
# tensor([5267,  138], device='cuda:0')
# tensor([5590, 2869], device='cuda:0')
# tensor([ 138, 1592], device='cuda:0')
# tensor([2869, 8507], device='cuda:0')
# tensor([1592, 1142], device='cuda:0')
# tensor([8507, 8507], device='cuda:0')
# tensor([1142,  426], device='cuda:0')
# tensor([765, 765], device='cuda:0')
# tensor([ 426, 5354], device='cuda:0')
# tensor([ 765, 7444], device='cuda:0')
# tensor([5354, 4855], device='cuda:0')
# tensor([7444, 7444], device='cuda:0')
# tensor([4855, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 6626], device='cuda:0')
# tensor([2047, 2047], device='cuda:0')
# tensor([6626, 2341], device='cuda:0')
# tensor([2047, 3618], device='cuda:0')
# tensor([2341, 1837], device='cuda:0')
# tensor([3618, 6158], device='cuda:0')
# tensor([1837, 3185], device='cuda:0')
# tensor([6158, 1065], device='cuda:0')
# tensor([3185, 1941], device='cuda:0')
# tensor([1065, 1065], device='cuda:0')
# tensor([1941, 2774], device='cuda:0')
# tensor([7451, 7451], device='cuda:0')
# tensor([2774, 4737], device='cuda:0')
# tensor([7451, 7451], device='cuda:0')
# tensor([4737, 3643], device='cuda:0')
# tensor([4605, 4605], device='cuda:0')
# tensor([3643, 7838], device='cuda:0')
# tensor([4605, 8507], device='cuda:0')
# tensor([7838, 4398], device='cuda:0')
# tensor([8507, 8507], device='cuda:0')
# tensor([4398, 7297], device='cuda:0')
# tensor([1162, 1162], device='cuda:0')
# tensor([7297, 3252], device='cuda:0')
# tensor([1162, 1255], device='cuda:0')
# tensor([3252, 3252], device='cuda:0')
# tensor([1255, 3705], device='cuda:0')
# tensor([6314, 6314], device='cuda:0')
# tensor([3705, 3236], device='cuda:0')
# tensor([6314, 6314], device='cuda:0')
# tensor([3236,  215], device='cuda:0')
# tensor([6058, 6058], device='cuda:0')
# tensor([ 215, 5573], device='cuda:0')
# tensor([6058, 2712], device='cuda:0')
# tensor([5573, 6850], device='cuda:0')
# tensor([2712, 7050], device='cuda:0')
# tensor([6850, 6850], device='cuda:0')
# tensor([7050, 5820], device='cuda:0')
# tensor([6058, 6058], device='cuda:0')
# tensor([5820, 3230], device='cuda:0')
# tensor([6058, 4464], device='cuda:0')
# tensor([3230, 2439], device='cuda:0')
# tensor([4464, 6400], device='cuda:0')
# tensor([2439, 2870], device='cuda:0')
# tensor([6400, 6400], device='cuda:0')
# tensor([2870, 5214], device='cuda:0')
# tensor([3722, 3722], device='cuda:0')
# tensor([5214, 2604], device='cuda:0')
# tensor([3722, 7050], device='cuda:0')
# tensor([2604, 8001], device='cuda:0')
# tensor([7050, 7253], device='cuda:0')
# tensor([8001, 8001], device='cuda:0')
# tensor([7253, 6734], device='cuda:0')
# tensor([7280, 7280], device='cuda:0')
# tensor([6734, 4136], device='cuda:0')
# tensor([7280, 4462], device='cuda:0')
# tensor([4136, 6056], device='cuda:0')
# tensor([4462, 1401], device='cuda:0')
# tensor([6056, 4051], device='cuda:0')
# tensor([1401, 7815], device='cuda:0')
# tensor([4051, 6734], device='cuda:0')
# tensor([7815, 7815], device='cuda:0')
# tensor([6734, 3854], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3854, 3857], device='cuda:0')
# tensor([7050, 7050], device='cuda:0')
# tensor([3857, 7020], device='cuda:0')
# tensor([7050,  794], device='cuda:0')
# tensor([7020, 7355], device='cuda:0')
# tensor([794, 794], device='cuda:0')
# tensor([7355, 3618], device='cuda:0')
# tensor([2661, 2661], device='cuda:0')
# tensor([3618, 6801], device='cuda:0')
# tensor([2661, 2661], device='cuda:0')
# tensor([6801, 6807], device='cuda:0')
# tensor([8663, 8663], device='cuda:0')
# tensor([6807, 5104], device='cuda:0')
# tensor([8663, 5825], device='cuda:0')
# tensor([5104,  586], device='cuda:0')
# tensor([5825, 6593], device='cuda:0')
# tensor([ 586, 6555], device='cuda:0')
# tensor([6593, 7228], device='cuda:0')
# tensor([6555, 5039], device='cuda:0')
# tensor([7228, 5043], device='cuda:0')
# tensor([5039, 2366], device='cuda:0')
# tensor([5043,  162], device='cuda:0')
# tensor([2366, 5949], device='cuda:0')
# tensor([ 162, 4468], device='cuda:0')
# tensor([5949, 6327], device='cuda:0')
# tensor([4468, 4468], device='cuda:0')
# tensor([6327,  162], device='cuda:0')
# tensor([3705, 3705], device='cuda:0')
# tensor([ 162, 2352], device='cuda:0')
# tensor([3705, 6238], device='cuda:0')
# tensor([2352, 7530], device='cuda:0')
# tensor([6238, 6538], device='cuda:0')
# tensor([7530, 7451], device='cuda:0')
# tensor([6538, 5343], device='cuda:0')
# tensor([7451, 7451], device='cuda:0')
# tensor([5343, 7436], device='cuda:0')
# tensor([632, 632], device='cuda:0')
# tensor([7436, 2604], device='cuda:0')
# tensor([ 632, 3205], device='cuda:0')
# tensor([2604, 2604], device='cuda:0')
# tensor([3205, 8368], device='cuda:0')
# tensor([45, 45], device='cuda:0')
# tensor([8368, 8368], device='cuda:0')
# tensor([  45, 3854], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3854, 3857], device='cuda:0')
# tensor([8411, 8411], device='cuda:0')
# tensor([3857, 1067], device='cuda:0')
# tensor([8411, 8552], device='cuda:0')
# tensor([1067,  693], device='cuda:0')
# tensor([8552, 8552], device='cuda:0')
# tensor([ 693, 3021], device='cuda:0')
# tensor([7853, 7853], device='cuda:0')
# tensor([3021, 3722], device='cuda:0')
# tensor([7853, 7853], device='cuda:0')
# tensor([3722, 7742], device='cuda:0')
# tensor([929, 929], device='cuda:0')
# tensor([7742, 1822], device='cuda:0')
# tensor([ 929, 7050], device='cuda:0')
# tensor([1822, 1822], device='cuda:0')
# tensor([7050, 5820], device='cuda:0')
# tensor([1086, 1086], device='cuda:0')
# tensor([5820, 2869], device='cuda:0')
# tensor([1086, 6235], device='cuda:0')
# tensor([2869, 2604], device='cuda:0')
# tensor([6235, 2869], device='cuda:0')
# tensor([2604, 4013], device='cuda:0')
# tensor([2869, 7514], device='cuda:0')
# tensor([4013, 6345], device='cuda:0')
# tensor([7514, 8017], device='cuda:0')
# tensor([6345, 3687], device='cuda:0')
# tensor([8017, 2033], device='cuda:0')
# tensor([3687, 3687], device='cuda:0')
# tensor([2033, 7050], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([7050, 4980], device='cuda:0')
# tensor([5190, 5190], device='cuda:0')
# tensor([4980, 3488], device='cuda:0')
# tensor([5190, 1769], device='cuda:0')
# tensor([3488,  693], device='cuda:0')
# tensor([1769, 1785], device='cuda:0')
# tensor([ 693, 3050], device='cuda:0')
# tensor([1785, 8605], device='cuda:0')
# tensor([3050, 6340], device='cuda:0')
# tensor([8605, 7050], device='cuda:0')
# tensor([6340, 6340], device='cuda:0')
# tensor([7050, 7050], device='cuda:0')
# tensor([7056, 7056], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([7056, 6311], device='cuda:0')
# tensor([7102, 7102], device='cuda:0')
# tensor([6311, 3618], device='cuda:0')
# tensor([7102, 7530], device='cuda:0')
# tensor([3618,  802], device='cuda:0')
# tensor([7530, 1455], device='cuda:0')
# tensor([ 802, 3549], device='cuda:0')
# tensor([1455, 2396], device='cuda:0')
# tensor([3549,   63], device='cuda:0')
# tensor([2396, 2396], device='cuda:0')
# tensor([  63, 2396], device='cuda:0')
# tensor([3021, 3021], device='cuda:0')
# tensor([2396, 2396], device='cuda:0')
# tensor([3021,  632], device='cuda:0')
# tensor([2073, 2073], device='cuda:0')
# tensor([ 632, 4266], device='cuda:0')
# tensor([2073, 5825], device='cuda:0')
# tensor([4266,  171], device='cuda:0')
# tensor([5825, 1781], device='cuda:0')
# tensor([ 171, 6443], device='cuda:0')
# tensor([1781, 1781], device='cuda:0')
# tensor([6443, 4159], device='cuda:0')
# tensor([7050, 7050], device='cuda:0')
# tensor([4159, 1255], device='cuda:0')
# tensor([7050, 2601], device='cuda:0')
# tensor([1255, 7637], device='cuda:0')
# tensor([2601, 2601], device='cuda:0')
# tensor([7637, 6558], device='cuda:0')
# tensor([5818, 5818], device='cuda:0')
# tensor([6558, 5669], device='cuda:0')
# tensor([5818, 3875], device='cuda:0')
# tensor([5669, 4730], device='cuda:0')
# tensor([3875, 1255], device='cuda:0')
# tensor([4730, 5655], device='cuda:0')
# tensor([1255, 1255], device='cuda:0')
# tensor([5655, 1227], device='cuda:0')
# tensor([4626, 4626], device='cuda:0')
# tensor([1227, 1255], device='cuda:0')
# tensor([4626, 2341], device='cuda:0')
# tensor([1255, 1255], device='cuda:0')
# tensor([2341, 6985], device='cuda:0')
# tensor([8001, 8001], device='cuda:0')
# tensor([6985, 6985], device='cuda:0')
# tensor([8001, 8470], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8470, 4453], device='cuda:0')
# tensor([3147, 3147], device='cuda:0')
# tensor([4453, 4453], device='cuda:0')
# tensor([3147, 7050], device='cuda:0')
# tensor([6580, 6580], device='cuda:0')
# tensor([7050, 1934], device='cuda:0')
# tensor([6580, 6580], device='cuda:0')
# tensor([1934, 1798], device='cuda:0')
# tensor([4236, 4236], device='cuda:0')
# tensor([1798, 1798], device='cuda:0')
# tensor([4236, 4592], device='cuda:0')
# tensor([7699, 7699], device='cuda:0')
# tensor([4592, 5494], device='cuda:0')
# tensor([7699, 4709], device='cuda:0')
# tensor([5494, 7398], device='cuda:0')
# tensor([4709, 3812], device='cuda:0')
# tensor([7398, 4790], device='cuda:0')
# tensor([3812, 6633], device='cuda:0')
# tensor([4790, 5087], device='cuda:0')
# tensor([6633, 6633], device='cuda:0')
# tensor([5087, 1470], device='cuda:0')
# tensor([4453, 4453], device='cuda:0')
# tensor([1470, 3147], device='cuda:0')
# tensor([4453, 2175], device='cuda:0')
# tensor([3147, 2870], device='cuda:0')
# tensor([2175,  234], device='cuda:0')
# tensor([2870, 1302], device='cuda:0')
# tensor([234, 450], device='cuda:0')
# tensor([1302, 8578], device='cuda:0')
# tensor([ 450, 6158], device='cuda:0')
# tensor([8578, 8578], device='cuda:0')
# tensor([6158, 3073], device='cuda:0')
# tensor([2744, 2744], device='cuda:0')
# tensor([3073, 3073], device='cuda:0')
# tensor([2744, 1284], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([1284, 5106], device='cuda:0')
# tensor([5416, 5416], device='cuda:0')
# tensor([5106, 3412], device='cuda:0')
# tensor([5416, 5416], device='cuda:0')
# tensor([3412, 2489], device='cuda:0')
# tensor([5494, 5494], device='cuda:0')
# tensor([2489, 8196], device='cuda:0')
# tensor([5494, 6767], device='cuda:0')
# tensor([8196, 8196], device='cuda:0')
# tensor([6767, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605,  544], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([ 544, 1781], device='cuda:0')
# tensor([8414, 8414], device='cuda:0')
# tensor([1781, 2870], device='cuda:0')
# tensor([8414,  951], device='cuda:0')
# tensor([2870, 1510], device='cuda:0')
# tensor([ 951, 4650], device='cuda:0')
# tensor([1510, 5158], device='cuda:0')
# tensor([4650, 7346], device='cuda:0')
# tensor([5158, 8416], device='cuda:0')
# tensor([7346, 3259], device='cuda:0')
# tensor([8416, 7056], device='cuda:0')
# tensor([3259, 3259], device='cuda:0')
# tensor([7056, 4272], device='cuda:0')
# tensor([135, 135], device='cuda:0')
# tensor([4272, 4774], device='cuda:0')
# tensor([135, 312], device='cuda:0')
# tensor([4774, 7355], device='cuda:0')
# tensor([ 312, 6950], device='cuda:0')
# tensor([7355, 2791], device='cuda:0')
# tensor([6950, 3302], device='cuda:0')
# tensor([2791,  476], device='cuda:0')
# tensor([3302, 8549], device='cuda:0')
# tensor([476, 476], device='cuda:0')
# tensor([8549, 4453], device='cuda:0')
# tensor([2357, 2357], device='cuda:0')
# tensor([4453, 6850], device='cuda:0')
# tensor([2357, 2169], device='cuda:0')
# tensor([6850, 4397], device='cuda:0')
# tensor([2169, 5311], device='cuda:0')
# tensor([4397, 4397], device='cuda:0')
# tensor([5311, 2298], device='cuda:0')
# tensor([4108, 4108], device='cuda:0')
# tensor([2298, 2298], device='cuda:0')
# tensor([4108, 7523], device='cuda:0')
# tensor([2061, 2061], device='cuda:0')
# tensor([7523, 7523], device='cuda:0')
# tensor([2061, 4462], device='cuda:0')
# tensor([8696, 8696], device='cuda:0')
# tensor([4462, 3902], device='cuda:0')
# tensor([8696, 8696], device='cuda:0')
# tensor([3902, 1993], device='cuda:0')
# tensor([4660, 4660], device='cuda:0')
# tensor([1993, 7646], device='cuda:0')
# tensor([4660, 5644], device='cuda:0')
# tensor([7646,  547], device='cuda:0')
# tensor([5644, 5644], device='cuda:0')
# tensor([ 547, 3651], device='cuda:0')
# tensor([4284, 4284], device='cuda:0')
# tensor([3651, 3651], device='cuda:0')
# tensor([4284, 7974], device='cuda:0')
# tensor([2190, 2190], device='cuda:0')
# tensor([7974, 4141], device='cuda:0')
# tensor([2190, 2862], device='cuda:0')
# tensor([4141, 4141], device='cuda:0')
# tensor([2862, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 8090], device='cuda:0')
# tensor([2598, 2598], device='cuda:0')
# tensor([8090, 3549], device='cuda:0')
# tensor([2598, 2189], device='cuda:0')
# tensor([3549, 5369], device='cuda:0')
# tensor([2189, 5587], device='cuda:0')
# tensor([5369,  929], device='cuda:0')
# tensor([5587, 3106], device='cuda:0')
# tensor([ 929, 5742], device='cuda:0')
# tensor([3106, 2869], device='cuda:0')
# tensor([5742, 7484], device='cuda:0')
# tensor([2869, 5991], device='cuda:0')
# tensor([7484, 7484], device='cuda:0')
# tensor([5991, 2189], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([2189, 7823], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([7823, 8573], device='cuda:0')
# tensor([3302, 3302], device='cuda:0')
# tensor([8573, 6679], device='cuda:0')
# tensor([3302, 2411], device='cuda:0')
# tensor([6679, 5012], device='cuda:0')
# tensor([2411, 2411], device='cuda:0')
# tensor([5012,  177], device='cuda:0')
# tensor([6869, 6869], device='cuda:0')
# tensor([177, 903], device='cuda:0')
# tensor([6869, 4750], device='cuda:0')
# tensor([903, 903], device='cuda:0')
# tensor([4750, 5522], device='cuda:0')
# tensor([3346, 3346], device='cuda:0')
# tensor([5522, 5522], device='cuda:0')
# tensor([3346, 6304], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([6304,   24], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([  24, 3892], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3892, 1432], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([1432, 6944], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([6944, 6936], device='cuda:0')
# tensor([4751, 4751], device='cuda:0')
# tensor([6936, 3618], device='cuda:0')
# tensor([4751, 3147], device='cuda:0')
# tensor([3618, 8069], device='cuda:0')
# tensor([3147, 8001], device='cuda:0')
# tensor([8069, 8069], device='cuda:0')
# tensor([8001, 4700], device='cuda:0')
# tensor([3463, 3463], device='cuda:0')
# tensor([4700, 6919], device='cuda:0')
# tensor([3463, 7099], device='cuda:0')
# tensor([6919, 3136], device='cuda:0')
# tensor([7099, 8144], device='cuda:0')
# tensor([3136, 3136], device='cuda:0')
# tensor([8144, 7544], device='cuda:0')
# tensor([6936, 6936], device='cuda:0')
# tensor([7544, 6167], device='cuda:0')
# tensor([6936, 6058], device='cuda:0')
# tensor([6167, 6167], device='cuda:0')
# tensor([6058, 8170], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8170, 3539], device='cuda:0')
# tensor([2396, 2396], device='cuda:0')
# tensor([3539, 8064], device='cuda:0')
# tensor([2396, 3618], device='cuda:0')
# tensor([8064, 8064], device='cuda:0')
# tensor([3618, 8654], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8654, 8654], device='cuda:0')
# tensor([162, 162], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([ 162, 6818], device='cuda:0')
# tensor([6707, 6707], device='cuda:0')
# tensor([6818, 6818], device='cuda:0')
# tensor([6707, 2902], device='cuda:0')
# tensor([8633, 8633], device='cuda:0')
# tensor([2902, 5386], device='cuda:0')
# tensor([8633, 1594], device='cuda:0')
# tensor([5386,  173], device='cuda:0')
# tensor([1594, 1594], device='cuda:0')
# tensor([ 173, 7979], device='cuda:0')
# tensor([1989, 1989], device='cuda:0')
# tensor([7979, 7979], device='cuda:0')
# tensor([1989, 6297], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([6297, 3194], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3194, 4354], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([4354, 6278], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([6278,  162], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([ 162, 5688], device='cuda:0')
# tensor([4295, 4295], device='cuda:0')
# tensor([5688, 3438], device='cuda:0')
# tensor([4295, 2927], device='cuda:0')
# tensor([3438, 3438], device='cuda:0')
# tensor([2927, 7514], device='cuda:0')
# tensor([7544, 7544], device='cuda:0')
# tensor([7514, 6986], device='cuda:0')
# tensor([7544,  693], device='cuda:0')
# tensor([6986, 6986], device='cuda:0')
# tensor([ 693, 2870], device='cuda:0')
# tensor([3050, 3050], device='cuda:0')
# tensor([2870, 2870], device='cuda:0')
# tensor([3050, 3539], device='cuda:0')
# tensor([2869, 2869], device='cuda:0')
# tensor([3539, 1001], device='cuda:0')
# tensor([2869, 6336], device='cuda:0')
# tensor([1001,  488], device='cuda:0')
# tensor([6336, 5406], device='cuda:0')
# tensor([488, 488], device='cuda:0')
# tensor([5406, 3617], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3617, 7286], device='cuda:0')
# tensor([1462, 1462], device='cuda:0')
# tensor([7286,  397], device='cuda:0')
# tensor([1462,  415], device='cuda:0')
# tensor([ 397, 2073], device='cuda:0')
# tensor([415, 415], device='cuda:0')
# tensor([2073, 2073], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([183, 183], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([ 183, 2756], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([2756, 1553], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([1553, 2626], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([2626, 6264], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([6264, 6264], device='cuda:0')
# tensor([2332, 2332], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([2332, 2332], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([1993, 1993], device='cuda:0')
# tensor([671, 671], device='cuda:0')
# tensor([1993, 2870], device='cuda:0')
# tensor([ 671, 7457], device='cuda:0')
# tensor([2870, 6179], device='cuda:0')
# tensor([7457, 7457], device='cuda:0')
# tensor([6179, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605,  555], device='cuda:0')
# tensor([1227, 1227], device='cuda:0')
# tensor([ 555, 4020], device='cuda:0')
# tensor([1227,  882], device='cuda:0')
# tensor([4020, 7139], device='cuda:0')
# tensor([ 882, 4712], device='cuda:0')
# tensor([7139, 7139], device='cuda:0')
# tensor([4712, 2966], device='cuda:0')
# tensor([5113, 5113], device='cuda:0')
# tensor([2966,  213], device='cuda:0')
# tensor([5113, 7451], device='cuda:0')
# tensor([213, 213], device='cuda:0')
# tensor([7451, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 7623], device='cuda:0')
# tensor([6818, 6818], device='cuda:0')
# tensor([7623, 6707], device='cuda:0')
# tensor([6818, 2902], device='cuda:0')
# tensor([6707, 5319], device='cuda:0')
# tensor([2902, 5730], device='cuda:0')
# tensor([5319,  754], device='cuda:0')
# tensor([5730,  162], device='cuda:0')
# tensor([ 754, 1772], device='cuda:0')
# tensor([162, 162], device='cuda:0')
# tensor([1772,  520], device='cuda:0')
# tensor([4895, 4895], device='cuda:0')
# tensor([520, 520], device='cuda:0')
# tensor([4895, 8466], device='cuda:0')
# tensor([6058, 6058], device='cuda:0')
# tensor([8466, 8466], device='cuda:0')
# tensor([6058, 4047], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([4047, 1700], device='cuda:0')
# tensor([7514, 7514], device='cuda:0')
# tensor([1700, 4841], device='cuda:0')
# tensor([7514, 4488], device='cuda:0')
# tensor([4841, 4841], device='cuda:0')
# tensor([4488, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3000], device='cuda:0')
# tensor([4012, 4012], device='cuda:0')
# tensor([3000,  255], device='cuda:0')
# tensor([4012, 4012], device='cuda:0')
# tensor([ 255, 4415], device='cuda:0')
# tensor([6578, 6578], device='cuda:0')
# tensor([4415, 4415], device='cuda:0')
# tensor([6578, 2990], device='cuda:0')
# tensor([8615, 8615], device='cuda:0')
# tensor([2990, 6162], device='cuda:0')
# tensor([8615, 5593], device='cuda:0')
# tensor([6162, 2025], device='cuda:0')
# tensor([5593, 2305], device='cuda:0')
# tensor([2025, 6926], device='cuda:0')
# tensor([2305, 7444], device='cuda:0')
# tensor([6926, 2377], device='cuda:0')
# tensor([7444, 7444], device='cuda:0')
# tensor([2377, 2189], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([2189, 1124], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([1124, 4737], device='cuda:0')
# tensor([7698, 7698], device='cuda:0')
# tensor([4737, 1880], device='cuda:0')
# tensor([7698, 1089], device='cuda:0')
# tensor([1880, 7152], device='cuda:0')
# tensor([1089, 4960], device='cuda:0')
# tensor([7152, 7152], device='cuda:0')
# tensor([4960, 8412], device='cuda:0')
# tensor([6710, 6710], device='cuda:0')
# tensor([8412, 5318], device='cuda:0')
# tensor([6710, 3072], device='cuda:0')
# tensor([5318, 5318], device='cuda:0')
# tensor([3072, 6311], device='cuda:0')
# tensor([2670, 2670], device='cuda:0')
# tensor([6311, 6311], device='cuda:0')
# tensor([2670, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 1255], device='cuda:0')
# tensor([3024, 3024], device='cuda:0')
# tensor([1255, 1255], device='cuda:0')
# tensor([3024, 7622], device='cuda:0')
# tensor([7050, 7050], device='cuda:0')
# tensor([7622, 7197], device='cuda:0')
# tensor([7050, 8453], device='cuda:0')
# tensor([7197, 5280], device='cuda:0')
# tensor([8453, 6898], device='cuda:0')
# tensor([5280, 8527], device='cuda:0')
# tensor([6898, 3529], device='cuda:0')
# tensor([8527,  693], device='cuda:0')
# tensor([3529, 2305], device='cuda:0')
# tensor([ 693, 6926], device='cuda:0')
# tensor([2305, 2305], device='cuda:0')
# tensor([6926, 4742], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([4742,  693], device='cuda:0')
# tensor([3826, 3826], device='cuda:0')
# tensor([ 693, 1465], device='cuda:0')
# tensor([3826, 2870], device='cuda:0')
# tensor([1465, 1465], device='cuda:0')
# tensor([2870, 8486], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8486, 5745], device='cuda:0')
# tensor([1162, 1162], device='cuda:0')
# tensor([5745, 5745], device='cuda:0')
# tensor([1162, 7050], device='cuda:0')
# tensor([8670, 8670], device='cuda:0')
# tensor([7050, 7050], device='cuda:0')
# tensor([8670, 4774], device='cuda:0')
# tensor([6677, 6677], device='cuda:0')
# tensor([4774, 2756], device='cuda:0')
# tensor([6677, 3134], device='cuda:0')
# tensor([2756, 2756], device='cuda:0')
# tensor([3134, 7918], device='cuda:0')
# tensor([6666, 6666], device='cuda:0')
# tensor([7918, 3975], device='cuda:0')
# tensor([6666, 6734], device='cuda:0')
# tensor([3975, 3975], device='cuda:0')
# tensor([6734, 6360], device='cuda:0')
# tensor([4242, 4242], device='cuda:0')
# tensor([6360, 1354], device='cuda:0')
# tensor([4242, 4242], device='cuda:0')
# tensor([1354, 4632], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([4632, 8405], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8405, 1465], device='cuda:0')
# tensor([4774, 4774], device='cuda:0')
# tensor([1465, 1465], device='cuda:0')
# tensor([4774, 4113], device='cuda:0')
# tensor([1465, 1465], device='cuda:0')
# tensor([4113, 7050], device='cuda:0')
# tensor([1465, 6883], device='cuda:0')
# tensor([7050, 7451], device='cuda:0')
# tensor([6883, 6883], device='cuda:0')
# tensor([7451, 8605], device='cuda:0')
# tensor([6340, 6340], device='cuda:0')
# tensor([8605, 8605], device='cuda:0')
# tensor([6340, 8413], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8413, 8413], device='cuda:0')
# tensor([4816, 4816], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([4816, 2204], device='cuda:0')
# tensor([7175, 7175], device='cuda:0')
# tensor([2204, 7050], device='cuda:0')
# tensor([7175, 7175], device='cuda:0')
# tensor([7050, 3272], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3272, 7044], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([7044, 6507], device='cuda:0')
# tensor([4701, 4701], device='cuda:0')
# tensor([6507,  135], device='cuda:0')
# tensor([4701, 7050], device='cuda:0')
# tensor([ 135, 8182], device='cuda:0')
# tensor([7050, 7050], device='cuda:0')
# tensor([8182, 6936], device='cuda:0')
# tensor([2396, 2396], device='cuda:0')
# tensor([6936, 6639], device='cuda:0')
# tensor([2396, 2396], device='cuda:0')
# tensor([6639, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 5518], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([5518, 4333], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([4333, 2596], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([2596, 7050], device='cuda:0')
# tensor([5575, 5575], device='cuda:0')
# tensor([7050, 7050], device='cuda:0')
# tensor([5575, 5407], device='cuda:0')
# tensor([3826, 3826], device='cuda:0')
# tensor([5407, 5407], device='cuda:0')
# tensor([3826, 7225], device='cuda:0')
# tensor([321, 321], device='cuda:0')
# tensor([7225, 1769], device='cuda:0')
# tensor([ 321, 2870], device='cuda:0')
# tensor([1769, 1769], device='cuda:0')
# tensor([2870, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 1065], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([1065, 5431], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([5431,  550], device='cuda:0')
# tensor([7433, 7433], device='cuda:0')
# tensor([550, 550], device='cuda:0')
# tensor([7433,  135], device='cuda:0')
# tensor([5361, 5361], device='cuda:0')
# tensor([ 135, 6507], device='cuda:0')
# tensor([5361, 4701], device='cuda:0')
# tensor([6507, 1465], device='cuda:0')
# tensor([4701, 2377], device='cuda:0')
# tensor([1465,  929], device='cuda:0')
# tensor([2377, 1255], device='cuda:0')
# tensor([ 929, 4462], device='cuda:0')
# tensor([1255, 6339], device='cuda:0')
# tensor([4462, 5216], device='cuda:0')
# tensor([6339, 3609], device='cuda:0')
# tensor([5216, 7149], device='cuda:0')
# tensor([3609, 3609], device='cuda:0')
# tensor([7149, 3205], device='cuda:0')
# tensor([1886, 1886], device='cuda:0')
# tensor([3205, 4459], device='cuda:0')
# tensor([1886, 1886], device='cuda:0')
# tensor([4459, 8587], device='cuda:0')
# tensor([4459, 4459], device='cuda:0')
# tensor([8587, 8587], device='cuda:0')
# tensor([4459, 8527], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8527, 8527], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8527, 8527], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8527, 5773], device='cuda:0')
# tensor([4398, 4398], device='cuda:0')
# tensor([5773, 8527], device='cuda:0')
# tensor([4398, 6495], device='cuda:0')
# tensor([8527, 8527], device='cuda:0')
# tensor([6495, 8527], device='cuda:0')
# tensor([3549, 3549], device='cuda:0')
# tensor([8527,   55], device='cuda:0')
# tensor([3549, 5481], device='cuda:0')
# tensor([55, 55], device='cuda:0')
# tensor([5481, 8527], device='cuda:0')
# tensor([937, 937], device='cuda:0')
# tensor([8527, 8527], device='cuda:0')
# tensor([ 937, 8527], device='cuda:0')
# tensor([1637, 1637], device='cuda:0')
# tensor([8527, 1637], device='cuda:0')
# tensor([1637, 8527], device='cuda:0')
# tensor([1637, 1637], device='cuda:0')
# tensor([8527, 8527], device='cuda:0')
# tensor([5762, 5762], device='cuda:0')
# tensor([8527, 3095], device='cuda:0')
# tensor([5762, 5762], device='cuda:0')
# tensor([3095, 2689], device='cuda:0')
# tensor([8527, 8527], device='cuda:0')
# tensor([2689, 2689], device='cuda:0')
# tensor([8527, 6622], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([6622,  500], device='cuda:0')
# tensor([8092, 8092], device='cuda:0')
# tensor([ 500, 8691], device='cuda:0')
# tensor([8092, 8064], device='cuda:0')
# tensor([8691, 8691], device='cuda:0')
# tensor([8064, 3886], device='cuda:0')
# tensor([5658, 5658], device='cuda:0')
# tensor([3886, 4774], device='cuda:0')
# tensor([5658, 4219], device='cuda:0')
# tensor([4774, 2057], device='cuda:0')
# tensor([4219, 2870], device='cuda:0')
# tensor([2057,  509], device='cuda:0')
# tensor([2870, 8501], device='cuda:0')
# tensor([ 509, 7256], device='cuda:0')
# tensor([8501,  889], device='cuda:0')
# tensor([7256, 7256], device='cuda:0')
# tensor([ 889, 8255], device='cuda:0')
# tensor([4398, 4398], device='cuda:0')
# tensor([8255, 8255], device='cuda:0')
# tensor([4398, 6850], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([6850, 1981], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([1981, 7849], device='cuda:0')
# tensor([7517, 7517], device='cuda:0')
# tensor([7849, 7849], device='cuda:0')
# tensor([7517, 8269], device='cuda:0')
# tensor([4175, 4175], device='cuda:0')
# tensor([8269, 8269], device='cuda:0')
# tensor([4175, 8566], device='cuda:0')
# tensor([1654, 1654], device='cuda:0')
# tensor([8566, 8566], device='cuda:0')
# tensor([1654, 3858], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3858, 3858], device='cuda:0')
# tensor([2790, 2790], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([2790, 2790], device='cuda:0')
# tensor([2181, 2181], device='cuda:0')
# tensor([6835, 6835], device='cuda:0')
# tensor([2181, 7612], device='cuda:0')
# tensor([6835, 7669], device='cuda:0')
# tensor([7612, 4399], device='cuda:0')
# tensor([7669, 4742], device='cuda:0')
# tensor([4399, 4399], device='cuda:0')
# tensor([4742, 6666], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([6666, 4378], device='cuda:0')
# tensor([7726, 7726], device='cuda:0')
# tensor([4378, 7792], device='cuda:0')
# tensor([7726, 2745], device='cuda:0')
# tensor([7792, 7792], device='cuda:0')
# tensor([2745, 8064], device='cuda:0')
# tensor([5107, 5107], device='cuda:0')
# tensor([8064, 1017], device='cuda:0')
# tensor([5107, 3883], device='cuda:0')
# tensor([1017,  929], device='cuda:0')
# tensor([3883, 5397], device='cuda:0')
# tensor([ 929, 7792], device='cuda:0')
# tensor([5397, 1335], device='cuda:0')
# tensor([7792, 7433], device='cuda:0')
# tensor([1335, 1335], device='cuda:0')
# tensor([7433, 7955], device='cuda:0')
# tensor([2820, 2820], device='cuda:0')
# tensor([7955, 7955], device='cuda:0')
# tensor([2820, 3823], device='cuda:0')
# tensor([2357, 2357], device='cuda:0')
# tensor([3823, 4804], device='cuda:0')
# tensor([2357, 7391], device='cuda:0')
# tensor([4804, 4804], device='cuda:0')
# tensor([7391, 4397], device='cuda:0')
# tensor([5311, 5311], device='cuda:0')
# tensor([4397, 4397], device='cuda:0')
# tensor([5311, 7262], device='cuda:0')
# tensor([330, 330], device='cuda:0')
# tensor([7262, 6728], device='cuda:0')
# tensor([ 330, 8404], device='cuda:0')
# tensor([6728, 8000], device='cuda:0')
# tensor([8404, 5135], device='cuda:0')
# tensor([8000, 3345], device='cuda:0')
# tensor([5135, 5135], device='cuda:0')
# tensor([3345, 8269], device='cuda:0')
# tensor([8314, 8314], device='cuda:0')
# tensor([8269, 8269], device='cuda:0')
# tensor([8314, 8619], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8619, 1255], device='cuda:0')
# tensor([6277, 6277], device='cuda:0')
# tensor([1255, 1255], device='cuda:0')
# tensor([6277, 8111], device='cuda:0')
# tensor([3886, 3886], device='cuda:0')
# tensor([8111, 4774], device='cuda:0')
# tensor([3886, 3886], device='cuda:0')
# tensor([4774, 2576], device='cuda:0')
# tensor([8398, 8398], device='cuda:0')
# tensor([2576, 2576], device='cuda:0')
# tensor([8398, 7522], device='cuda:0')
# tensor([6158, 6158], device='cuda:0')
# tensor([7522, 8571], device='cuda:0')
# tensor([6158, 7003], device='cuda:0')
# tensor([8571, 1638], device='cuda:0')
# tensor([7003, 7003], device='cuda:0')
# tensor([1638, 1926], device='cuda:0')
# tensor([207, 207], device='cuda:0')
# tensor([1926, 1926], device='cuda:0')
# tensor([207, 721], device='cuda:0')
# tensor([5534, 5534], device='cuda:0')
# tensor([ 721, 2382], device='cuda:0')
# tensor([5534, 2379], device='cuda:0')
# tensor([2382, 2382], device='cuda:0')
# tensor([2379, 4957], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([4957, 7664], device='cuda:0')
# tensor([2820, 2820], device='cuda:0')
# tensor([7664, 7664], device='cuda:0')
# tensor([2820, 2820], device='cuda:0')
# tensor([6936, 6936], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([6936, 3465], device='cuda:0')
# tensor([5940, 5940], device='cuda:0')
# tensor([3465, 2576], device='cuda:0')
# tensor([5940, 3332], device='cuda:0')
# tensor([2576, 1491], device='cuda:0')
# tensor([3332, 3332], device='cuda:0')
# tensor([1491, 6958], device='cuda:0')
# tensor([7787, 7787], device='cuda:0')
# tensor([6958, 7029], device='cuda:0')
# tensor([7787, 1519], device='cuda:0')
# tensor([7029, 1571], device='cuda:0')
# tensor([1519, 1519], device='cuda:0')
# tensor([1571, 2491], device='cuda:0')
# tensor([481, 481], device='cuda:0')
# tensor([2491, 3549], device='cuda:0')
# tensor([481, 481], device='cuda:0')
# tensor([3549, 3549], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([6269, 6269], device='cuda:0')
# tensor([5931, 5931], device='cuda:0')
# tensor([6269, 4545], device='cuda:0')
# tensor([5931, 4954], device='cuda:0')
# tensor([4545, 4821], device='cuda:0')
# tensor([4954, 6850], device='cuda:0')
# tensor([4821, 2870], device='cuda:0')
# tensor([6850, 7262], device='cuda:0')
# tensor([2870, 6602], device='cuda:0')
# tensor([7262, 7262], device='cuda:0')
# tensor([6602, 2057], device='cuda:0')
# tensor([45, 45], device='cuda:0')
# tensor([2057, 3975], device='cuda:0')
# tensor([45, 45], device='cuda:0')
# tensor([3975,  693], device='cuda:0')
# tensor([5216, 5216], device='cuda:0')
# tensor([693, 247], device='cuda:0')
# tensor([5216, 8332], device='cuda:0')
# tensor([247, 247], device='cuda:0')
# tensor([8332, 8578], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8578, 8578], device='cuda:0')
# tensor([3185, 3185], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3185, 1065], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([1065, 1065], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([8306, 8306], device='cuda:0')
# tensor([3549, 3549], device='cuda:0')
# tensor([8306, 2447], device='cuda:0')
# tensor([3549, 6311], device='cuda:0')
# tensor([2447, 3812], device='cuda:0')
# tensor([6311, 1542], device='cuda:0')
# tensor([3812, 4837], device='cuda:0')
# tensor([1542, 1542], device='cuda:0')
# tensor([4837, 1377], device='cuda:0')
# tensor([3917, 3917], device='cuda:0')
# tensor([1377, 5318], device='cuda:0')
# tensor([3917, 7355], device='cuda:0')
# tensor([5318, 7020], device='cuda:0')
# tensor([7355, 5731], device='cuda:0')
# tensor([7020, 3269], device='cuda:0')
# tensor([5731, 1775], device='cuda:0')
# tensor([3269, 4644], device='cuda:0')
# tensor([1775, 7106], device='cuda:0')
# tensor([4644,  192], device='cuda:0')
# tensor([7106, 7106], device='cuda:0')
# tensor([ 192, 7593], device='cuda:0')
# tensor([1298, 1298], device='cuda:0')
# tensor([7593, 3618], device='cuda:0')
# tensor([1298, 2870], device='cuda:0')
# tensor([3618, 3618], device='cuda:0')
# tensor([2870, 1124], device='cuda:0')
# tensor([6933, 6933], device='cuda:0')
# tensor([1124, 1124], device='cuda:0')
# tensor([6933, 7545], device='cuda:0')
# tensor([2870, 2870], device='cuda:0')
# tensor([7545, 4800], device='cuda:0')
# tensor([2870, 1298], device='cuda:0')
# tensor([4800, 5937], device='cuda:0')
# tensor([1298, 1298], device='cuda:0')
# tensor([5937, 5937], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 1419], device='cuda:0')
# tensor([4267, 4267], device='cuda:0')
# tensor([1419, 8306], device='cuda:0')
# tensor([4267, 3549], device='cuda:0')
# tensor([8306, 2256], device='cuda:0')
# tensor([3549, 1255], device='cuda:0')
# tensor([2256, 6306], device='cuda:0')
# tensor([1255, 8507], device='cuda:0')
# tensor([6306, 6306], device='cuda:0')
# tensor([8507, 4267], device='cuda:0')
# tensor([8306, 8306], device='cuda:0')
# tensor([4267, 1663], device='cuda:0')
# tensor([8306, 4923], device='cuda:0')
# tensor([1663, 6306], device='cuda:0')
# tensor([4923, 8507], device='cuda:0')
# tensor([6306, 6306], device='cuda:0')
# tensor([8507, 8595], device='cuda:0')
# tensor([2550, 2550], device='cuda:0')
# tensor([8595, 8595], device='cuda:0')
# tensor([2550, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 2841], device='cuda:0')
# tensor([4387, 4387], device='cuda:0')
# tensor([2841,  766], device='cuda:0')
# tensor([4387, 4267], device='cuda:0')
# tensor([ 766, 2560], device='cuda:0')
# tensor([4267, 1111], device='cuda:0')
# tensor([2560, 7920], device='cuda:0')
# tensor([1111, 4685], device='cuda:0')
# tensor([7920, 7920], device='cuda:0')
# tensor([4685, 2990], device='cuda:0')
# tensor([8573, 8573], device='cuda:0')
# tensor([2990, 2581], device='cuda:0')
# tensor([8573, 8573], device='cuda:0')
# tensor([2581, 2581], device='cuda:0')
# tensor([1255, 1255], device='cuda:0')
# tensor([3826, 3826], device='cuda:0')
# tensor([1255, 8507], device='cuda:0')
# tensor([3826, 4990], device='cuda:0')
# tensor([8507, 2870], device='cuda:0')
# tensor([4990,  693], device='cuda:0')
# tensor([2870, 1004], device='cuda:0')
# tensor([693, 693], device='cuda:0')
# tensor([1004, 1302], device='cuda:0')
# tensor([1255, 1255], device='cuda:0')
# tensor([1302, 6194], device='cuda:0')
# tensor([1255, 1255], device='cuda:0')
# tensor([6194, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605,  555], device='cuda:0')
# tensor([5573, 5573], device='cuda:0')
# tensor([ 555, 6538], device='cuda:0')
# tensor([5573, 4751], device='cuda:0')
# tensor([6538, 2555], device='cuda:0')
# tensor([4751, 6282], device='cuda:0')
# tensor([2555, 6013], device='cuda:0')
# tensor([6282, 1476], device='cuda:0')
# tensor([6013, 3954], device='cuda:0')
# tensor([1476, 4240], device='cuda:0')
# tensor([3954, 3954], device='cuda:0')
# tensor([4240, 7433], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([7433, 3954], device='cuda:0')
# tensor([4240, 4240], device='cuda:0')
# tensor([3954, 5594], device='cuda:0')
# tensor([4240, 7050], device='cuda:0')
# tensor([5594, 1255], device='cuda:0')
# tensor([7050, 5100], device='cuda:0')
# tensor([1255, 8165], device='cuda:0')
# tensor([5100, 5165], device='cuda:0')
# tensor([8165, 8165], device='cuda:0')
# tensor([5165, 5013], device='cuda:0')
# tensor([7197, 7197], device='cuda:0')
# tensor([5013, 6340], device='cuda:0')
# tensor([7197, 2604], device='cuda:0')
# tensor([6340,  248], device='cuda:0')
# tensor([2604, 8578], device='cuda:0')
# tensor([ 248, 3616], device='cuda:0')
# tensor([8578, 2239], device='cuda:0')
# tensor([3616, 2904], device='cuda:0')
# tensor([2239, 2858], device='cuda:0')
# tensor([2904, 7005], device='cuda:0')
# tensor([2858, 2858], device='cuda:0')
# tensor([7005, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 3605], device='cuda:0')
# tensor([8576, 8576], device='cuda:0')
# tensor([3605, 2259], device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb Cell 13 line 7
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X15sZmlsZQ%3D%3D?line=72'>73</a> loss = loss_func(log_probs.view(1,-1), autograd.Variable(
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X15sZmlsZQ%3D%3D?line=73'>74</a>     torch.LongTensor([word_to_ix[target.translate(str.maketrans("", "", string.punctuation))]]).to('cuda')
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X15sZmlsZQ%3D%3D?line=74'>75</a> ))
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X15sZmlsZQ%3D%3D?line=76'>77</a> loss.backward()
# ---> <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X15sZmlsZQ%3D%3D?line=77'>78</a> optimizer.step()
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X15sZmlsZQ%3D%3D?line=79'>80</a> iterations += 1
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X15sZmlsZQ%3D%3D?line=80'>81</a> total_loss += loss.data
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/optim/optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/optim/optimizer.py:76, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
#      75     torch._dynamo.graph_break()
# ---> 76     ret = func(self, *args, **kwargs)
#      77 finally:
#      78     torch._dynamo.graph_break()
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/optim/sgd.py:75, in SGD.step(self, closure)
#      71 momentum_buffer_list = []
#      73 has_sparse_grad = self._init_group(group, params_with_grad, d_p_list, momentum_buffer_list)
# ---> 75 sgd(params_with_grad,
#      76     d_p_list,
#      77     momentum_buffer_list,
#      78     weight_decay=group['weight_decay'],
#      79     momentum=group['momentum'],
#      80     lr=group['lr'],
#      81     dampening=group['dampening'],
#      82     nesterov=group['nesterov'],
#      83     maximize=group['maximize'],
#      84     has_sparse_grad=has_sparse_grad,
#      85     foreach=group['foreach'])
#      87 # update momentum_buffers in state
#      88 for p, momentum_buffer in zip(params_with_grad, momentum_buffer_list):
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/optim/sgd.py:220, in sgd(params, d_p_list, momentum_buffer_list, has_sparse_grad, foreach, weight_decay, momentum, lr, dampening, nesterov, maximize)
#     217 else:
#     218     func = _single_tensor_sgd
# --> 220 func(params,
#     221      d_p_list,
#     222      momentum_buffer_list,
#     223      weight_decay=weight_decay,
#     224      momentum=momentum,
#     225      lr=lr,
#     226      dampening=dampening,
#     227      nesterov=nesterov,
#     228      has_sparse_grad=has_sparse_grad,
#     229      maximize=maximize)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/optim/sgd.py:327, in _multi_tensor_sgd(params, grads, momentum_buffer_list, weight_decay, momentum, lr, dampening, nesterov, maximize, has_sparse_grad)
#     324         device_grads = bufs
#     326 if not device_has_sparse_grad:
# --> 327     torch._foreach_add_(device_params, device_grads, alpha=-lr)
#     328 else:
#     329     # foreach APIs don't support sparse
#     330     for i in range(len(device_params)):
#
# KeyboardInterrupt:

# %%
list(word_to_ix.keys()).__len__()
# Out:
# 8702

# %%
context = ['why', 'apology']
print(word_to_ix)
context_var = make_context_vector(context, word_to_ix)
print(context_var)

log_probs = net(context_var)

key_list = list(word_to_ix.keys())
val_list = list(word_to_ix.values())

print(log_probs.argmax())

print(key_list[val_list.index(log_probs.argmax())])
# Out:
# {'pseudo': 0, 'divorce': 1, 'treat': 2, 'discuss': 3, 'sulk': 4, 'dern': 5, 'undercover': 6, 'height': 7, 'column': 8, 'determine': 9, 'apology': 10, 'ford': 11, 'smell': 12, 'afterlife': 13, 'urge': 14, 'forewarn': 15, 'filth': 16, 'craze': 17, 'cafe': 18, 'laura': 19, 'shopping': 20, 'june': 21, 'la': 22, 'builder': 23, 'delight': 24, 'satisfied': 25, 'mafioso': 26, 'magazine': 27, 'owner': 28, 'vibrant': 29, 'madkaughmovie': 30, 'protestant': 31, 'unconventional': 32, 'hack': 33, 'valid': 34, 'wars': 35, 'family': 36, 'pm': 37, 'offs': 38, 'schneider': 39, 'cling': 40, 'captain': 41, 'ordinary': 42, 'rendition': 43, 'stunned': 44, 'performance': 45, 'alert': 46, 'official': 47, 'yakima': 48, 'snot': 49, 'dracula': 50, 'pilot': 51, 'derek': 52, 'separate': 53, 'megaloadon': 54, 'video': 55, 'rental': 56, 'improvisation': 57, 'bowl': 58, 'bargain': 59, 'simon': 60, '06': 61, 'plentiful': 62, 'cuff': 63, 'lobotomy': 64, 'curiously': 65, 'sea': 66, 'sparseness': 67, 'montana': 68, 'ball': 69, 'mocumentary': 70, 'raise': 71, 'smith': 72, 'x100': 73, 'disc': 74, 'brett': 75, 'uplift': 76, 'btw': 77, 'drown': 78, 'even': 79, 'animation': 80, 'unrecognizable': 81, 'jeffery': 82, 'equally': 83, 'poop': 84, 'yellow': 85, 'tenser': 86, 'krakowsky': 87, 'schwarzenegger': 88, 'type': 89, 'paralysis': 90, 'pickle': 91, 'twitch': 92, 'unemployed': 93, 'thursday': 94, 'believed': 95, 'progressively': 96, 'ceremony': 97, 'justify': 98, 'final': 99, 'descriptive': 100, '100': 101, 'modeling': 102, 'neccessary': 103, 'kinky': 104, 'haired': 105, 'destine': 106, 'vocalist': 107, 'freakin': 108, 'reputation': 109, 'overact': 110, 'pun': 111, 'skinned': 112, 'engaging': 113, 'moderately': 114, 'nice': 115, 'ominous': 116, 'contradict': 117, 'defense': 118, 'powell': 119, 'few': 120, 'undeniably': 121, 'hairstyle': 122, 'installment': 123, 'bet': 124, 'strike': 125, 'newscaster': 126, 'ustinov': 127, 'adaptation': 128, 'arden': 129, 'aussie': 130, 'female': 131, 'firmly': 132, 'honcho': 133, 'presidential': 134, 'tell': 135, 'roster': 136, 'elevation': 137, 'homeless': 138, 'superior': 139, 'symbolism': 140, 'punish': 141, 'scorsese': 142, 'corruption': 143, 'redo': 144, 'speaking': 145, 'brigitte': 146, 'soundboard': 147, 'attend': 148, 'district': 149, 'suite': 150, 'surgical': 151, 'pontoon': 152, 'geographically': 153, 'rain': 154, 'street': 155, 'poison': 156, 'vehicle': 157, 'attempt': 158, 'playing': 159, 'raw': 160, 'intolerance': 161, 'hand': 162, 'schroder': 163, 'juvinile': 164, 'comconnoisseur': 165, 'transsexual': 166, 'karol': 167, 'riverside': 168, 'spaceball': 169, 'earphone': 170, 'huge': 171, 'maniacal': 172, 'understand': 173, 'yike': 174, 'insane': 175, 'alternate': 176, 'wide': 177, 'ultimately': 178, 'muller': 179, 'lightning': 180, 'bed': 181, 'reflection': 182, 'mention': 183, 'college': 184, 'bachelor': 185, 'yell': 186, 'magda': 187, 'endearing': 188, 'infinity': 189, 'logic': 190, 'kane': 191, 'hollywood': 192, 'doable': 193, 'clerk': 194, 'logically': 195, 'filmographie': 196, 'regan': 197, 'reservation': 198, 'nearly': 199, 'threesome': 200, 'woah': 201, 'mirren': 202, 'hannah': 203, 'spacecraft': 204, 'fourth': 205, 'lovemaking': 206, 'boost': 207, 'ps': 208, 'unflattering': 209, 'scenery': 210, 'cheesiest': 211, 'idea': 212, 'true': 213, 'dippity': 214, 'second': 215, 'loose': 216, 'blunder': 217, 'relive': 218, 'weigh': 219, 'storytelling': 220, 'outcome': 221, 'wholesome': 222, 'disease': 223, 'wayne': 224, 'brat': 225, 'momma': 226, '14': 227, 'spiritual': 228, 'insular': 229, 'watching': 230, 'fight': 231, 'overrate': 232, 'robbin': 233, 'pretense': 234, 'randolph': 235, 'pinhead': 236, 'corleone': 237, 'carnosaur': 238, 'research': 239, 'mega': 240, 'bah': 241, 'realistic': 242, 'appetizer': 243, '10movie': 244, 'digest': 245, 'exhibition': 246, 'horserace': 247, 'leave': 248, 'profundity': 249, 'catholic': 250, 'cook': 251, 'understandably': 252, 'enchanted': 253, 'scheduler': 254, 'mild': 255, 'wave': 256, 's ...
# tensor([1419,   10], device='cuda:0')
# tensor(1419, device='cuda:0')
# why
