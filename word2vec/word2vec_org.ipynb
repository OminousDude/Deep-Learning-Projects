# %%
import torch
import torch.nn as nn
import torch.autograd as autograd
import torch.optim as optim
import torch.nn.functional as F
import spacy
import pandas as pd
import re
import string
from time import time

# %%
df = pd.read_csv('imdb_master.csv', encoding="latin-1")
df.shape
# Out:
# (499, 5)

# %%
df = df.drop(['type', 'label', 'file', 'Unnamed: 0'], axis=1)
# df = df.drop(['raw_character_text'], axis=1)

# %%
df.head()
# Out:
#                                               review
# 0  Once again Mr. Costner has dragged out a movie...
# 1  This is an example of why the majority of acti...
# 2  First of all I hate those moronic rappers, who...
# 3  Not even the Beatles could write songs everyon...
# 4  Brass pictures (movies is not a fitting word f...

# %%
df.isnull().sum()
# Out:
# review    0
# dtype: int64

# %%
df = df.dropna().reset_index(drop=True)
df.isnull().sum()
# Out:
# review    0
# dtype: int64

# %%
nlp = spacy.load('en_core_web_sm')

def cleaning(doc):
    txt = [token.lemma_ for token in doc if not token.is_stop]
    if len(txt) > 2:
        return ' '.join(txt)

# %%
brief_cleaning = (str(row).lower() for row in df['review'])

# %%
t = time()

txt = [cleaning(doc) for doc in nlp.pipe(brief_cleaning, batch_size=5000)]

# %%
df_clean = pd.DataFrame({'clean': txt})
df_clean = df_clean.dropna().drop_duplicates()
df_clean.shape
# Out:
# (499, 1)

# %%
all_txt = ""

for row in df_clean['clean']:
    all_txt = all_txt + row

# %%
class CBOW(nn.Module):
    def __init__(self, context_size=2, embedding_size=256, vocab_size=None):
        super(CBOW, self).__init__()
        self.embeddings = nn.Embedding(vocab_size, embedding_size)
        self.linear1 = nn.Linear(embedding_size, embedding_size*2)
        self.linear2 = nn.Linear(embedding_size*2, vocab_size)
        # self.linear3 = nn.Linear(embedding_size*4, embedding_size*8)
        # self.linear4 = nn.Linear(embedding_size*8, vocab_size)

    def forward(self, inputs):
        lookup_embeds = self.embeddings(inputs)
        embeds = lookup_embeds.sum(dim=0)
        out = nn.LeakyReLU()(self.linear1(embeds))
        out = nn.LeakyReLU()(self.linear2(out))
        # out = nn.LeakyReLU()(self.linear3(out))
        # out = nn.LeakyReLU()(self.linear4(out))
        out = F.log_softmax(out, dim=0)
        return out

# %%
def make_context_vector(context, word_to_ix):
    idxs = [word_to_ix[w] for w in context]
    tensor = torch.LongTensor(idxs).to('cuda')
    return autograd.Variable(tensor)

# %%
CONTEXT_SIZE = 1
EMBEDDING_SIZE = 256
# raw_text = all_txt.split()
raw_text = re.findall( r'\w+|[^\s\w]+', all_txt)

vocab = set(raw_text)
vocab_size = len(vocab)

word_to_ix = {word: i for i, word in enumerate(vocab)}
print(word_to_ix.keys())

word_to_ix_ = {}

i = 0
for row in word_to_ix:
    word_to_ix_[row.translate(str.maketrans("", "", string.punctuation))] = i
    i += 1

word_to_ix = word_to_ix_

print(word_to_ix.keys())

data = []
for i in range(2, len(raw_text) - 2):
    context = [raw_text[i - 1].translate(str.maketrans("", "", string.punctuation)), raw_text[i + 1].translate(str.maketrans("", "", string.punctuation))]
    target = raw_text[i]
    data.append((context, target))

loss_func = nn.CrossEntropyLoss()
net = CBOW(CONTEXT_SIZE, embedding_size=EMBEDDING_SIZE, vocab_size=vocab_size).to('cuda')
optimizer = optim.SGD(net.parameters(), lr=0.005)

for epoch in range(30):
    total_loss = 0
    for context, target in data:
        context_ = context

        i = 0
        for val in context:
            context_[i] = val.translate(str.maketrans("", "", string.punctuation))
            i += 1

        context_var = make_context_vector(context, word_to_ix)
        net.zero_grad()
        log_probs = net(context_var)

        loss = loss_func(log_probs.view(1,-1), autograd.Variable(
            torch.LongTensor([word_to_ix[target.translate(str.maketrans("", "", string.punctuation))]]).to('cuda')
        ))

        loss.backward()
        optimizer.step()

        total_loss += loss.data
    print(total_loss)
# Out:
# dict_keys(['naked', 'program', 'grandmother', 'juggernaut', 'page', 'pale', 'dramatically', 'hang', 'angela', 'workplace', 'still', '1821', 'corruption', 'achievement', 'propaganda', 'getaway', 'leslie', 'pic', 'spout', 'sf', 'mankind', 'tube', 'excellent', 'fantastic', 'celebrity', 'muscle', 'flitty', 'mainly', 'elwe', 'dispose', 'theatrical', 'obsessive', 'collide', 'campfire', 'period', 'linklater', 'sharp', 'publicly', 'electric', 'voting', 'heist', 'tissue', 'ripoff', 'thoroughly', 'trap', 'memorize', 'ol', 'joey', 'fertile', 'noise', 'gomeda', 'require', 'parents', 'excessive', 'western', 'singer', 'scare', 'toxic', 'rotten', '64', 'english', 'carrot', 'disclaimer', 'catharsis', 'nighttime', 'victory', 'positive', 'goal', 'torment', 'weirdos', 'manner', 'forerunner', 'cg', 'stableman', 'restraining', 'tape', 'mainstream', 'tux', 'maniacal', 'recognizable', 'store', 'satisfied', 'allowance', 'fishie', 'yacht', 'millionaire', 'panicky', 'fony', 'hateful', 'exaggerated', 'mum', 'law', 'loathing', 'mean', 'cloak', 'over', 'thisï', 'isabella', 'questionable', 'laughnaked', 'mural', 'behavior', 'married', 'punchline', 'unlikable', 'electra', 'anorexic', 'bys', 'silent', 'antichrist', 'provocative', 'infamously', 'nastiness', 'jamie', '...', 'unlike', 'blind', 'splice', 'experimentation', 'strand', 'twitch', 'approaches', 'choreographer', 'wrestling', 'gold', 'fence', 'meaningful', 'girlfriend', 'mcentire', 'fanatic', 'fedora', 'discourage', 'filler', 'purpose', 'highbrow', 'accuracy', 'paradiso', 'stinker', 'philosophy', 'achieve', 'intro', 'impressive', 'fond', 'transfixed', 'materialistic', 'iii', 'prey', 'dismissible', 'suprise', 'riddle', 'piper', 'thigh', 'approach', 'deanna', 'credence', 'anyways', 'disfigured', 'walken', 'timethink', 'school', 'lynch', 'incoherent', 'supervise', 'giggling', 'compliance', 'assets', 'hopefully', 'slavery', 'proportion', 'mercifully', 'brutus', 'elevator', 'farce', 'strangle', 'investment', 'crucial', 'iv', 'systematically', 'nod', 'relive', 'resort', 'drum', 'extraordinarily', 'nonesensical', 'interchangeable', 'chill', 'gasp', 'retain', 'sake', 'huh', 'park', 'lethal', 'pleasure', 'â', 'secondary', 'glass', 'boot', 'tense', 'legacy', 'immortality', 'krull', 'shameless', 'rocker', 'beater', 'manure', 'kameej', 'n', 'meyer', 'indian', 'debauchery', 'glare', 'unstoppable', 'noname', 'rehash', 'officially', 'jimmy', 'ubiquitous', 'christiano', 'thankfully', 'crazy', 'treat', 'design', 'boooring', 'xxx', 'singing', 'hasting', 'iota', 'constitute', 'pisser', 'fluid', 'whalley', 'ominous', ':(', 'fiance', 'tell', 'fx', 'bishop', 'aesthetically', 'brave', 'mushy', 'rancher', 'misogyny', 'finale', 'recall', 'collect', 'delineate', 'upstande', 'evoke', 'alb', 'dehl', 'we', 'oprah', 'mortuary', 'alma', 'vacation', 'orion', 'gushing', 'possession', '1934', 'oblivious', 'breast', 'mexican', 'ignore', 'did', 'whoo', 'enslave', 'land', 'proxy', 'oblivion', 'drinker', 'regrettable', 'bloke', 'sweeping', 'complicated', 'norm', 'goblin', 'none', 'gigantically', 'remove', 'union', 'separately', 'unclaimed', 'develop', 'philip', 'olga', 'brooch', 'historical', 'ass', 'absolute', 'continuous', 'sully', 'hallelujah', 'dolph', 'provocation', 'rot', 'obituary', 'erickson', 'uber', 'jeopardy', 'russ', 'wal', 'notable', 'badman', 'hackers', 'wilderness', 'sellecca', 'poirot', 'russians', 'shout', 'obsess', 'uhhh', 'fabienne', 'wafer', 'iqs', 'idiotic', 'parts', 'admire', 'mouse', 'investigator', 'dirty', 'backyard', 'unrated', 'feasible', '-"', 'chilean', '¯', 'disease', 'polluted', 'defend', 'international', 'jealous', 'gym', 'brutalize', 'modicum', 'southern', 'or', 'bapi', 'termite', 'rarely', 'atheistic', 'foot', 'ashton', 'sickly', 'caretaker', '1990', 'hope', 'concision', 'now', 'woodward', 'confused', 'probably', 'shoulder', 'colton', 'urban', 'honcho', 'hafta', 'an', 'slate', 'operate', 'dismissal', 'laundry', 'dammit', 'slight', 'letterman', 'such', 'taxi', 'badly', ':<', 'infinitely', 'terry', 'season', ...
# dict_keys(['naked', 'program', 'grandmother', 'juggernaut', 'page', 'pale', 'dramatically', 'hang', 'angela', 'workplace', 'still', '1821', 'corruption', 'achievement', 'propaganda', 'getaway', 'leslie', 'pic', 'spout', 'sf', 'mankind', 'tube', 'excellent', 'fantastic', 'celebrity', 'muscle', 'flitty', 'mainly', 'elwe', 'dispose', 'theatrical', 'obsessive', 'collide', 'campfire', 'period', 'linklater', 'sharp', 'publicly', 'electric', 'voting', 'heist', 'tissue', 'ripoff', 'thoroughly', 'trap', 'memorize', 'ol', 'joey', 'fertile', 'noise', 'gomeda', 'require', 'parents', 'excessive', 'western', 'singer', 'scare', 'toxic', 'rotten', '64', 'english', 'carrot', 'disclaimer', 'catharsis', 'nighttime', 'victory', 'positive', 'goal', 'torment', 'weirdos', 'manner', 'forerunner', 'cg', 'stableman', 'restraining', 'tape', 'mainstream', 'tux', 'maniacal', 'recognizable', 'store', 'satisfied', 'allowance', 'fishie', 'yacht', 'millionaire', 'panicky', 'fony', 'hateful', 'exaggerated', 'mum', 'law', 'loathing', 'mean', 'cloak', 'over', 'thisï', 'isabella', 'questionable', 'laughnaked', 'mural', 'behavior', 'married', 'punchline', 'unlikable', 'electra', 'anorexic', 'bys', 'silent', 'antichrist', 'provocative', 'infamously', 'nastiness', 'jamie', '', 'unlike', 'blind', 'splice', 'experimentation', 'strand', 'twitch', 'approaches', 'choreographer', 'wrestling', 'gold', 'fence', 'meaningful', 'girlfriend', 'mcentire', 'fanatic', 'fedora', 'discourage', 'filler', 'purpose', 'highbrow', 'accuracy', 'paradiso', 'stinker', 'philosophy', 'achieve', 'intro', 'impressive', 'fond', 'transfixed', 'materialistic', 'iii', 'prey', 'dismissible', 'suprise', 'riddle', 'piper', 'thigh', 'approach', 'deanna', 'credence', 'anyways', 'disfigured', 'walken', 'timethink', 'school', 'lynch', 'incoherent', 'supervise', 'giggling', 'compliance', 'assets', 'hopefully', 'slavery', 'proportion', 'mercifully', 'brutus', 'elevator', 'farce', 'strangle', 'investment', 'crucial', 'iv', 'systematically', 'nod', 'relive', 'resort', 'drum', 'extraordinarily', 'nonesensical', 'interchangeable', 'chill', 'gasp', 'retain', 'sake', 'huh', 'park', 'lethal', 'pleasure', 'â', 'secondary', 'glass', 'boot', 'tense', 'legacy', 'immortality', 'krull', 'shameless', 'rocker', 'beater', 'manure', 'kameej', 'n', 'meyer', 'indian', 'debauchery', 'glare', 'unstoppable', 'noname', 'rehash', 'officially', 'jimmy', 'ubiquitous', 'christiano', 'thankfully', 'crazy', 'treat', 'design', 'boooring', 'xxx', 'singing', 'hasting', 'iota', 'constitute', 'pisser', 'fluid', 'whalley', 'ominous', 'fiance', 'tell', 'fx', 'bishop', 'aesthetically', 'brave', 'mushy', 'rancher', 'misogyny', 'finale', 'recall', 'collect', 'delineate', 'upstande', 'evoke', 'alb', 'dehl', 'we', 'oprah', 'mortuary', 'alma', 'vacation', 'orion', 'gushing', 'possession', '1934', 'oblivious', 'breast', 'mexican', 'ignore', 'did', 'whoo', 'enslave', 'land', 'proxy', 'oblivion', 'drinker', 'regrettable', 'bloke', 'sweeping', 'complicated', 'norm', 'goblin', 'none', 'gigantically', 'remove', 'union', 'separately', 'unclaimed', 'develop', 'philip', 'olga', 'brooch', 'historical', 'ass', 'absolute', 'continuous', 'sully', 'hallelujah', 'dolph', 'provocation', 'rot', 'obituary', 'erickson', 'uber', 'jeopardy', 'russ', 'wal', 'notable', 'badman', 'hackers', 'wilderness', 'sellecca', 'poirot', 'russians', 'shout', 'obsess', 'uhhh', 'fabienne', 'wafer', 'iqs', 'idiotic', 'parts', 'admire', 'mouse', 'investigator', 'dirty', 'backyard', 'unrated', 'feasible', 'chilean', '¯', 'disease', 'polluted', 'defend', 'international', 'jealous', 'gym', 'brutalize', 'modicum', 'southern', 'or', 'bapi', 'termite', 'rarely', 'atheistic', 'foot', 'ashton', 'sickly', 'caretaker', '1990', 'hope', 'concision', 'now', 'woodward', 'confused', 'probably', 'shoulder', 'colton', 'urban', 'honcho', 'hafta', 'an', 'slate', 'operate', 'dismissal', 'laundry', 'dammit', 'slight', 'letterman', 'such', 'taxi', 'badly', 'infinitely', 'terry', 'season', 'play', 'tuning', 'c ...
# tensor(454452.3750, device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb Cell 14 line 5
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X16sZmlsZQ%3D%3D?line=44'>45</a> log_probs = net(context_var)
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X16sZmlsZQ%3D%3D?line=46'>47</a> loss = loss_func(log_probs.view(1,-1), autograd.Variable(
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X16sZmlsZQ%3D%3D?line=47'>48</a>     torch.LongTensor([word_to_ix[target.translate(str.maketrans("", "", string.punctuation))]]).to('cuda')
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X16sZmlsZQ%3D%3D?line=48'>49</a> ))
# ---> <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X16sZmlsZQ%3D%3D?line=50'>51</a> loss.backward()
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X16sZmlsZQ%3D%3D?line=51'>52</a> optimizer.step()
#      <a href='vscode-notebook-cell:/home/maxim/Documents/MyProjects/word2vec/word2vec.ipynb#X16sZmlsZQ%3D%3D?line=53'>54</a> total_loss += loss.data
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
list(word_to_ix.keys()).__len__()
# Out:
# 8703

# %%
context = ['i', 'hungry']
print(word_to_ix)
context_var = make_context_vector(context, word_to_ix)
print(context_var)

log_probs = net(context_var)

key_list = list(word_to_ix.keys())
val_list = list(word_to_ix.values())

print(log_probs.argmax())

print(key_list[val_list.index(log_probs.argmax())])
# Out:
# {'staple': 0, 'better': 1, 'burroughs': 2, 'memorable': 3, 'adama': 4, 'fantasy': 5, 'straight': 6, 'hardware': 7, 'brake': 8, 'clique': 9, 'pupil': 10, 'admirable': 11, 'contest': 12, 'reefer': 13, 'lotr': 14, '105': 15, 'glitter': 16, 'kindre': 17, 'daughter': 18, 'mindlessly': 19, 'offensive': 20, 'inside': 21, 'fest': 22, 'sheerly': 23, 'moderation': 24, 'deep': 25, 'culprit': 26, 'hike': 27, 'sulk': 28, 'ideology': 29, 'affleck': 30, 'general': 31, 'clothing': 32, 'do': 33, 'hapless': 34, 'cardinal': 35, 'platform': 36, 'enjoyment': 37, 'laura': 38, 'osaurus': 39, 'martin': 40, 'fourth': 41, 'influence': 42, 'schizophrenic': 43, 'sophisticated': 44, 'credit': 45, 'element': 46, 'ich': 47, 'strike': 48, 'attempt': 49, 'sector': 50, 'excessive': 51, 'willow': 52, 'gosh': 53, 'charge': 54, 'dehumanize': 55, 'asante': 56, 'mtv': 57, 'axe': 58, '1927': 59, 'hitchcock': 60, 'exertion': 61, 'unintended': 62, 'marc': 63, 'and': 64, 'lovely': 65, 'philadelphia': 66, 'methodist': 67, 'boldfaced': 68, 'deceive': 69, 'new': 70, 'betray': 71, 'collector': 72, 'ulysses': 73, '1980': 74, 'hyperspace': 75, 'faithfulness': 76, 'situation': 77, 'expendable': 78, 'misconstrue': 79, 'walker': 80, 'husen': 81, 'obesity': 82, 'hairstyle': 83, 'nomination': 84, 'connor': 85, 'baker': 86, 'extremist': 87, 'pride': 88, 'eg': 89, 'colour': 90, 'ellary': 91, 'suvs': 92, 'lurv': 93, 'revisit': 94, 'needle': 95, 'kindergarten': 96, 'collect': 97, 'exploration': 98, 'embark': 99, 'undeserving': 100, 'unattractive': 101, 'speed': 102, 'unlikeable': 103, 'dispatcher': 104, 'shameful': 105, 'work': 106, 'advancement': 107, 'rejoice': 108, 'fantastic': 109, 'hilary': 110, 'eva': 111, 'vestment': 112, 'lonely': 113, 'hitchhiker': 114, 'hope': 115, 'money': 116, 'biography': 117, 'recollection': 118, 'employ': 119, 'eyeful': 120, 'coogan': 121, '': 8793, 'dvd': 124, 'analyzing': 125, 'jake': 126, 'glum': 127, 'parents': 128, 'threaten': 130, 'liberal': 131, 'interlace': 132, 'surprised': 133, 'forewarn': 134, 'heretical': 135, 'hills': 137, 'johnson': 138, 'real': 139, 'summer': 140, 'punisher': 141, 'something': 142, 'overheade': 143, 'crap': 144, 'disconnect': 145, 'crash': 146, 'cruise': 148, 'scheme': 149, 'clockwork': 150, 'nay': 151, 'boooring': 152, 'infowarriorbother': 153, 'grace': 154, 'submit': 155, 'ritalin': 156, 'anytime': 157, 'confidence': 158, 'bug': 159, '1983': 160, 'estate': 161, 'goodness': 162, 'smug': 163, 'devotee': 164, 'jesse': 165, 'tug': 166, 'trait': 167, 'eroticism': 168, 'rating': 169, 'nosedive': 170, 'misleading': 171, 'secretary': 172, 'eastwick': 173, 'responsible': 174, 'pap': 175, 'lab': 176, 'complete': 177, 'weekend': 178, 'technically': 179, 'virtue': 180, 'std': 181, 'whereabout': 182, 'll': 183, 'seventy': 184, 'kidding': 185, 'xxx': 186, 'fx': 187, 'motivate': 188, 'continuity': 189, 'poirot': 191, 'wwii': 192, 'collar': 193, 'uninvolving': 194, 'mistakenly': 195, 'golden': 196, 'being': 197, 'shallow': 198, 'compelling': 199, 'terminator': 200, 'moronically': 201, 'pipe': 202, 'faculty': 203, 'witness': 204, 'benchmark': 205, 'radical': 206, 'hunter': 207, 'infect': 208, 'relative': 209, 'gosford': 210, 'sketchy': 211, 'caste': 212, 'root': 213, 'gigantically': 214, 'frightening': 215, 'employee': 216, 'investment': 217, 'guess': 218, 'column': 219, 'musical': 220, 'berkely': 221, 'stank': 222, 'ed': 223, 'cemetery': 224, 'titanic': 225, 'priesthole': 226, 'urge': 227, 'parts': 228, 'closet': 229, 'prefer': 230, 'scenes': 231, 'cage': 232, 'remarry': 233, 'escapee': 234, 'overlooked': 235, 'theme': 236, 'him': 237, 'reach': 238, 'agent': 239, 'guard': 240, 'unmistakably': 241, 'revision': 242, 'presentation': 243, 'jeep': 244, 'italians': 245, 'scream': 246, 'colored': 247, 'baritone': 248, 'rugby': 249, 'curfew': 250, 'kid': 251, 'especially': 252, 'j': 253, 'denham': 254, 'mutter': 255, 'federal': 256, 'filmographie': 257, 'impressive': 258, 'm': 259, 'final': 260, 'ride': 261, 'worker': 262, 'treatable': 263, ' ...
# tensor([7230, 2357], device='cuda:0')
# tensor(7659, device='cuda:0')
# try
